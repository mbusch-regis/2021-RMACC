# %% [markdown]
# # Multiprocessing with the Enron email corpus

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Who am I (and why do you care)?

# %% [markdown]
# * **Contact Info:**
#     * Mike Busch
#     * Regis University
#        * Assistant Professor - Data Science
#        * Undergraduate Data Science Director
#        * Data Science lab director
#     * mbusch@regis.edu
# <img align="right" style="padding-right:10px;" src="figures/symbiosdolphins.jpg" width=200><br>
# * **Background:**
#     * Computers since 1983
#         * Apple ]\[+, 48K RAM
#     * Work
#         * Symbios Logic
#     <img align="right" style="padding-right:10px;" src="figures/rogue-wave-software.svg" width=200><br>
#         * Rogue Wave Software
#         * McKesson medical software
#         * Regis University
#     * Education
#         * Doctorate - CTU
#             * Research: Genome assembly using GPUs and Hadoop
#         * Masters - Regis
#         * Bachelors - Regis
#     <img align="right" style="padding-right:10px;" src="figures/regis-university.jpg" width=200>
#     * Python - Intermediate
#         * Using since 2012
# * **Current Research**
#     * Computer vision and augmented reality of 3 dimensional objects
#         * Hardware:
#             * Microsoft Azure Kinect, HoloLens
#         * Software:
#             * OpenCV
#             * Open3D
#             * PyTorch
#             * Torch Points 3D

# %% [markdown]
# ## The what and why of multiprocessing

# %% [markdown]
# ### A tale of two threads

# %% [markdown]
# #### Parallel execution

# %% [markdown]
# <img align="left" style="padding-right:10px;" src="figures/thistall.jpg" width=400>

# %% [markdown]
# <p style="text-align:left;">-- Dave Baron, Mozilla developer</p>

# %% [markdown]
# **Background info - multithreading and multiprocessing**
#
# **Definitions**
#
# * **Process**-- Generally, one program
# * **Thread**-- "Lightweight" process that shares memory with other threads
# * **Multiprocessing**-- One program with multiple parallel processes
# * **Multithreading**-- Multiple threads sharing memory for parallel processing

# %% [markdown]
# <img align="right" style="padding-right:10px;" src="figures/Multithreaded_process.svg" width=400><br>
# [**History of Multithreading**](https://people.cs.clemson.edu/~mark/multithreading.html#:~:text=Summary%3A%20Multithreading%20first%20appeared%20in,investigated%20by%20IBM%20in%201968.&text=Most%20attempts%20at%20a%20history,PPUs%20in%20the%20CDC%206600.)
# Mark Smotherman, Nov. 2007
#
# > Summary: Multithreading first appeared in the 1950s, and simultaneous multithreading (SMT) was investigated by IBM in 1968.
#
# [Wikipedia: Thread (computing)](https://en.wikipedia.org/wiki/Thread_(computing))<br>
#
# * **Thread (of execution)** -- The smallest sequence of programmed instructions that can be managed independently by an OS scheduler, which is typically a part of the operating system.
#     * A thread is a component of a process.
#         * Multiple threads can exist within one process,
#         * Execute concurrently and share resources such as memory
#             * threads share process's executable code
#             * process's dynamically allocated variables and non-thread-local global variables
#
# * **Process** -- One "package" of executable code, memory, etc.
#     * Different processes do not share resources (usually).

# %% [markdown]
# <img align="center" style="padding-right:10px;" src="figures/Concepts-_Program_vs._Process_vs._Thread.jpg" width=800><br>

# %% [markdown]
# Many times, when we have large, slow tasks, we **break them up into smaller tasks and try to do more than one of them at once**. Although there are other definitions and uses, this is called **parallel processing**.
#
# Unfortunately, Python was written before "multi-core" CPUs were even a concept. Due to this, a shortcut was taken to mitigate inherent problems with multi-threading: the **Global Interpreter Lock (GIL).** When one Python thread is running on the CPU, the GIL locks out all other Python threads. Also unfortunately, the GIL is such a fundamental part of the Python interpreter, it cannot really be removed to take advantage of modern CPUs.
#
# All hope is not lost, though. Python has no problem with multi-processing -- allowing one program to control multiple independent processes that do not share memory with each other.
#
# Also, the GIL only comes into play when a slow process is **CPU-bound**, like a difficult math problem. I/O (input/output)-bound programs do not have to deal with the GIL.
#
# Since each email message resides on disk completely seperately from all other messages, there is nothing stopping us from reading several messages. Even though our mail parsing is I/O-bound, we will investigate multiprocessing to help speed up ingestion. **Note:** there are a few libraries and methods to help make multiprocessing easier but we will stay with the Python standard library tool, **concurrent futures.**

# %% [markdown]
# # Concurrent Speedup

# %% [markdown]
# The original idea to work with the new(ish) Concurrent library came from the KD Nuggets article [Get a 2–6x Speed-up on Your Data Pre-processing with Python](https://www.kdnuggets.com/2018/10/get-speed-up-data-pre-processing-python.html) used OpenCV to resize images.
#
# Unfortunately, Python 3.8 (which I am using) and concurrent.futures (for which this was originally written) have some compatibility problem. Therefore, instead of using `ProcessPoolExecutor()` and the `map()` function from concurrent.futures, I will be using `Pool()` and `map()` from the Multiprocessing library.
#
# This investigation has been adapted to reading and parsing the Enron dataset using Email library code from[Analysing the Enron Email Corpus](https://www.pythonforengineers.com/analysing-the-enron-email-corpus/)

# %% [markdown]
# ## Standard image processing, using single process

# %% [markdown]
# ```
# import glob
# import os
# import cv2
#
# ### Loop through all jpg files in the current folder
# ### Resize each one to size 600x600
#
# for image_filename in glob.glob("*.jpg"):
#
#   ### Read in the image data
#   img = cv2.imread(image_filename)
#
#   ### Resize the image
#   img = cv2.resize(img, (600, 600))
#   return img
# ```

# %% [markdown]
# ## Adding Multiprocessing

# %% [markdown]
# ```
# import glob
# import os
# import cv2
# #import concurrent.futures
#
# from multiprocess import Pool, Process, cpu_count
#
#
# def load_and_resize(image_filename):
#
#   ### Read in the image data
#   img = cv2.imread(image_filename)
#
#   ### Resize the image
#   img = cv2.resize(img, (600, 600))
#   return img
#
#
# ### Create a pool of processes.
# ### By default, one is created for each
# ### CPU in your machine.
#
# workers = cpu_count()
# with Pool(workers) as p:
#
#     ### Get a list of files to process
#     image_files = glob.glob("*.jpg")
#
#     ### Process the list of files,
#     ### but split the work across the
#     ### process pool to use all CPUs
#     ### Loop through all jpg files in the current folder
#     ### Resize each one to size 600x600
#     result = p.map(load_and_resize, image_files)
# ```

# %% [markdown]
# The line `workers = cpu_count()` gets a count of how many CPUs can (potentially) be used for processes.
#
# The line<br>
# `    with Pool(workers) as p:`<br>
# starts as many Python processes as the machine has CPU cores.
#
# Processing happens with this line:<br>
# `    p.map(load_and_resize, image_files)`
#
# The **p.map()** takes as input the function you would like to run and a list where each element of the list is a **single input to our function.**
#
# The data you are processing also needs to be a type that Python knows how to “pickle”. Luckily, these are quite common. From the official Python documentation:
#
# **Pickle-able** types:
# * None, True, and False
# * integers, floating point numbers, complex numbers
# * strings, bytes, bytearrays
# * tuples, lists, sets, and dictionaries containing only picklable objects
# * functions defined at the top level of a module (using def, not lambda)
# * built-in functions defined at the top level of a module
# * classes that are defined at the top level of a module
# * instances of such classes whose __dict__ or the result of calling __getstate__() is picklable (see section Pickling Class Instances for details).

# %% [markdown]
# # Our dataset

# %% [markdown]
# [Enron](https://en.wikipedia.org/wiki/Enron) was an energy company headquartered in Houston, Texas that was found in 2001 to be perpetrating a massive accounting fraud.
#
# More than 500,000 executive's email messages, totalling around 1.7GB after decompression.
#
# [email corpus home](https://www.cs.cmu.edu/~enron/)

# %% [markdown]
# ## Enron Emails

# %% [markdown]
# First, let's make sure we can access the directories:

# %%
import os

rootdir = "data/maildir"

# %%
for directory, subdirectory, filenames in  os.walk(rootdir):
    print(directory, subdirectory, len(filenames))
# Out:
# data/maildir ['rodrique-r', 'shapiro-r', 'jones-t', 'lewis-a', 'lay-k', 'slinger-r', 'arnold-j', 'saibi-e', 'mckay-j', 'kitchen-l', 'mims-thurston-p', 'king-j', 'harris-s', 'storey-g', 'horton-s', 'love-p', 'benson-r', 'schwieger-j', 'crandell-s', 'mann-k', 'haedicke-m', 'allen-p', 'staab-t', 'stokley-c', 'lavorato-j', 'shankman-j', 'martin-t', 'whalley-l', 'weldon-c', 'quigley-d', 'shively-h', 'dean-c', 'white-s', 'quenet-j', 'merriss-s', 'mckay-b', 'gang-l', 'reitmeyer-j', 'germany-c', 'presto-k', 'ward-k', 'hodge-j', 'may-l', 'causholli-m', 'scholtes-d', 'heard-m', 'hernandez-j', 'shackleton-s', 'ermis-f', 'gilbertsmith-d', 'nemec-g', 'baughman-d', 'phanis-s', 'grigsby-m', 'cash-m', 'sturm-f', 'salisbury-h', 'richey-c', 'williams-j', 'hain-m', 'kean-s', 'sanders-r', 'perlingiere-d', 'lucci-p', 'davis-d', 'fossum-d', 'gay-r', 'neal-s', 'rogers-b', 'pimenov-v', 'thomas-p', 'lokey-t', 'symes-k', 'beck-s', 'hyvl-d', 'meyers-a', 'geaccone-t', 'donohoe-t', 'hendrickson-s', 'skilling-j', 'platter-p', 'keavey-p', 'stclair-c', 'ruscitti-k', 'tycholiz-b', 'donoho-l', 'bailey-s', 'solberg-g', 'fischer-m', 'ybarbo-p', 'williams-w3', 'tholt-j', 'keiser-k', 'carson-m', 'derrick-j', 'buy-r', 'badeer-r', 'farmer-d', 'scott-s', 'hayslett-r', 'semperger-c', 'corman-s', 'giron-d', 'stepenovitch-j', 'bass-e', 'smith-m', 'swerzbin-m', 'taylor-m', 'dasovich-j', 'blair-l', 'wolfe-j', 'maggi-m', 'campbell-l', 'dorland-c', 'pereira-s', 'arora-h', 'hyatt-k', 'delainey-d', 'mccarty-d', 'kuykendall-t', 'sanchez-m', 'cuilla-m', 'lokay-m', 'griffith-j', 'ring-a', 'mcconnell-m', 'mclaughlin-e', 'south-s', 'sager-e', 'zufferli-j', 'whitt-m', 'panus-s', 'zipper-a', 'lenhart-m', 'rapp-b', 'linder-e', 'parks-j', 'forney-j', 'dickson-s', 'steffes-j', 'schoolcraft-d', 'ring-r', 'motley-m', 'brawner-s', 'watson-k', 'guzman-m', 'whalley-g', 'holst-k', 'townsend-j', 'kaminski-v'] 0
# data/maildir/rodrique-r ['dublin', '_sent_mail', 'all_documents', 'file', 'sent', 'canada', 'discussion_threads', 'israel_estrada'] 0
# data/maildir/rodrique-r/dublin [] 33
# data/maildir/rodrique-r/_sent_mail [] 721
# data/maildir/rodrique-r/all_documents [] 820
# data/maildir/rodrique-r/file [] 17
# data/maildir/rodrique-r/sent [] 721
# data/maildir/rodrique-r/canada [] 47
# data/maildir/rodrique-r/discussion_threads [] 406
# data/maildir/rodrique-r/israel_estrada [] 1
# data/maildir/shapiro-r ['retail_markets', 'refund_cases', 'fundamentals', 'bush_administration', 'florida', 'enron_online', 'organizational_issues', 'ken_lay', '2001_prc__midyear', 'western_governor_s_university', 'merchant_function_group', 'notre_dame', 'epsa', '2001_budget__cost_cutting', 'vp_prc', 'rail', 'doe', 'mid_atlantic', 'europe_october', 'sent_items', 'congrats', 'new_england_ny', 'caem', 'retail_operations', 'midwest', 'humor', 'naruc', 'contributions', 'lng', 'ferc', 'federal_gov_t_affairs', 'federal_legis_', 'speaking_engagements', 'enviromental', 'california_coverup', 'rto_campaign', 'staff_meetings', 'default_service__opportunities', 'all_documents', 'deleted_items', '2001_objectives', 'sce_deal', 'democrats', 'industrial_cust__solutions', 'training__gov_t__affairs', 'steel', 'tva', 'wholesale_markets', 'antitrust', 'europe', 'cftc', 'associations', 'rto_filings__order_2000', 'europe_june', 'synfuel_tax_crredits', 'forest_and_paper_products', 'pge_sale', 'coal', 'broadband_services', 'texas', 'california', 'risk_analytics', 'gas_issues', 'sec', 'price_risk_management_', 'rac', 'notes_inbox', 'investing', 'sent', 'resource_committment_req_s', 'national_campaign', 'granite__2_', 'patriotism', 'canada', 'west', '2001_witchunt', 'presentations', 'media', 'southern_cone', 'venezuela_colombia', 'personal', 'compliments', 'europe_july', 'japan', 'value', 'generation', 'personnel', 'policy_papers', 'discussion_threads', 'qf_s___risk_analysis', 'tax', 'southeast', 'mexico', 'shopping', '2001_budget', 'affiliate_codes_of_conduct', 'networks', 'hedging', 'interconnection_issues', 'india', 'global_markets', '2002_budget', 'pg_e_bankruptcy', 'market_structure__seabron_adamson_', 'fuel_cells', 'inbox', 'nerc', 'computers', 'personal_travel', 'california_legal_issues'] 0
# data/maildir/shapiro-r/retail_markets [] 29
# data/maildir/shapiro-r/refund_cases [] 16
# data/maildir/shapiro-r/fundamentals [] 2
# data/maildir/shapiro-r/bush_administration [] 1
# data/maildir/shapiro-r/florida [] 7
# data/maildir/shapiro-r/enron_online [] 14
# data/maildir/shapiro-r/organizational_issues [] 73
# data/maildir/shapiro-r/ken_lay [] 3
# data/maildir/shapiro-r/2001_prc__midyear [] 20
# data/maildir/shapiro-r/western_governor_s_university [] 1
# data/maildir/shapiro-r/merchant_function_group [] 2
# data/maildir/shapiro-r/notre_dame [] 56
# data/maildir/shapiro-r/epsa [] 5
# data/maildir/shapiro-r/2001_budget__cost_cutting [] 10
# data/maildir/shapiro-r/vp_prc [] 12
# data/maildir/shapiro-r/rail [] 3
# data/maildir/shapiro-r/doe [] 3
# data/maildir/shapiro-r/mid_atlantic [] 10
# data/maildir/shapiro-r/europe_october [] 9
# data/maildir/shapiro-r/sent_items [] 1
# data/maildir/shapiro-r/congrats [] 1
# data/maildir/shapiro-r/new_england_ny [] 22
# data/maildir/shapiro-r/caem [] 2
# data/maildir/shapiro-r/retail_operations [] 2
# data/maildir/shapiro-r/midwest [] 41
# data/maildir/shapiro-r/humor [] 28
# data/maildir/shapiro-r/naruc [] 2
# data/maildir/shapiro-r/contributions [] 8
# data/maildir/shapiro-r/lng [] 10
# data/maildir/shapiro-r/ferc [] 9
# data/maildir/shapiro-r/federal_gov_t_affairs [] 28
# data/maildir/shapiro-r/federal_legis_ [] 82
# data/maildir/shapiro-r/speaking_engagements [] 1
# data/maildir/shapiro-r/enviromental [] 18
# data/maildir/shapiro-r/california_coverup [] 5
# data/maildir/shapiro-r/rto_campaign ['show_cause_motion'] 57
# data/maildir/shapiro-r/rto_campaign/show_cause_motion [] 1
# data/maildir/shapiro-r/staff_meetings [] 1
# data/maildir/shapiro-r/default_service__opportunities [] 2
# data/maildir/shapiro-r/all_documents [] 1270
# data/maildir/shapiro-r/deleted_items ['caem', 'resource_committment_req_s', 'patriotism'] 1468
# data/maildir/shapiro-r/deleted_items/caem [] 1
# data/maildir/shapiro-r/deleted_items/resource_committment_req_s [] 2
# data/maildir/shapiro-r/deleted_items/patriotism [] 17
# data/maildir/shapiro-r/2001_objectives [] 18
# data/maildir/shapiro-r/sce_deal [] 4
# data/maildir/shapiro-r/democrats [] 8
# data/maildir/shapiro-r/industrial_cust__solutions [] 15
# data/maildir/shapiro-r/training__gov_t__affairs [] 1
# data/maildir/shapiro-r/steel [] 29
# data/maildir/shapiro-r/tva [] 6
# data/maildir/shapiro-r/wholesale_markets [] 65
# data/maildir/shapiro-r/antitrust [] 2
# data/maildir/shapiro-r/europe [] 60
# data/maildir/shapiro-r/cftc [] 6
# data/maildir/shapiro-r/associations [] 1
# data/maildir/shapiro-r/rto_filings__order_2000 [] 20
# data/maildir/shapiro-r/europe_june [] 33
# data/maildir/shapiro-r/synfuel_tax_crredits [] 6
# data/maildir/shapiro-r/forest_and_paper_products [] 2
# data/maildir/shapiro-r/pge_sale [] 2
# data/maildir/shapiro-r/coal [] 2
# data/maildir/shapiro-r/broadband_services [] 37
# data/maildir/shapiro-r/texas [] 23
# data/maildir/shapiro-r/california [] 181
# data/maildir/shapiro-r/risk_analytics [] 10
# data/maildir/shapiro-r/gas_issues [] 31
# data/maildir/shapiro-r/sec [] 1
# data/maildir/shapiro-r/price_risk_management_ [] 2
# data/maildir/shapiro-r/rac [] 10
# data/maildir/shapiro-r/notes_inbox [] 123
# data/maildir/shapiro-r/investing [] 1
# data/maildir/shapiro-r/sent [] 11
# data/maildir/shapiro-r/resource_committment_req_s [] 2
# data/maildir/shapiro-r/national_campaign [] 41
# data/maildir/shapiro-r/granite__2_ [] 18
# data/maildir/shapiro-r/patriotism [] 16
# data/maildir/shapiro-r/canada [] 79
# data/maildir/shapiro-r/west [] 18
# data/maildir/shapiro-r/2001_witchunt [] 3
# data/maildir/shapiro-r/presentations [] 1
# data/maildir/shapiro-r/media [] 3
# data/maildir/shapiro-r/southern_cone [] 55
# data/maildir/shapiro-r/venezuela_colombia [] 17
# data/maildir/shapiro-r/personal [] 101
# data/maildir/shapiro-r/compliments [] 28
# data/maildir/shapiro-r/europe_july [] 16
# data/maildir/shapiro-r/japan [] 21
# data/maildir/shapiro-r/value [] 43
# data/maildir/shapiro-r/generation ['europe_august'] 8
# data/maildir/shapiro-r/generation/europe_august [] 1
# data/maildir/shapiro-r/personnel [] 69
# data/maildir/shapiro-r/policy_papers [] 1
# data/maildir/shapiro-r/discussion_threads [] 1135
# data/maildir/shapiro-r/qf_s___risk_analysis [] 1
# data/maildir/shapiro-r/tax [] 6
# data/maildir/shapiro-r/southeast [] 4
# data/maildir/shapiro-r/mexico [] 9
# data/maildir/shapiro-r/shopping [] 7
# data/maildir/shapiro-r/2001_budget [] 21
# data/maildir/shapiro-r/affiliate_codes_of_conduct [] 5
# data/maildir/shapiro-r/networks [] 8
# data/maildir/shapiro-r/hedging [] 4
# data/maildir/shapiro-r/interconnection_issues [] 2
# data/maildir/shapiro-r/india [] 20
# data/maildir/shapiro-r/global_markets [] 16
# data/maildir/shapiro-r/2002_budget ['2001_budget'] 50
# data/maildir/shapiro-r/2002_budget/2001_budget [] 2
# data/maildir/shapiro-r/pg_e_bankruptcy [] 16
# data/maildir/shapiro-r/market_structure__seabron_adamson_ [] 16
# data/maildir/shapiro-r/fuel_cells [] 2
# data/maildir/shapiro-r/inbox [] 27
# data/maildir/shapiro-r/nerc [] 69
# data/maildir/shapiro-r/computers [] 1
# data/maildir/shapiro-r/personal_travel [] 1
# data/maildir/shapiro-r/california_legal_issues [] 43
# data/maildir/jones-t ['sent_items', 'master_notice', 'all_documents', 'deleted_items', 'trading_issues', 'online_trading', 'notes_inbox', 'sent', 'misc', 'inbox'] 0
# data/maildir/jones-t/sent_items [] 313
# data/maildir/jones-t/master_notice [] 2
# data/maildir/jones-t/all_documents [] 9304
# data/maildir/jones-t/deleted_items [] 66
# data/maildir/jones-t/trading_issues [] 20
# data/maildir/jones-t/online_trading [] 365
# data/maildir/jones-t/notes_inbox [] 5095
# data/maildir/jones-t/sent [] 3810
# data/maildir/jones-t/misc [] 18
# data/maildir/jones-t/inbox [] 957
# data/maildir/lewis-a ['sent_items', 'old_messages', '_sent_mail', 'all_documents', 'deleted_items', 'calendar', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/lewis-a/sent_items [] 26
# data/maildir/lewis-a/old_messages [] 14
# data/maildir/lewis-a/_sent_mail [] 38
# data/maildir/lewis-a/all_documents [] 203
# data/maildir/lewis-a/deleted_items [] 1359
# data/maildir/lewis-a/calendar [] 7
# data/maildir/lewis-a/notes_inbox [] 142
# data/maildir/lewis-a/sent [] 35
# data/maildir/lewis-a/discussion_threads [] 185
# data/maildir/lewis-a/inbox [] 182
# data/maildir/lay-k ['elizabeth', 'sent_items', 'business', 'family', 'all_documents', 'deleted_items', '_sent', 'calendar', 'notes_inbox', 'sent', 'enron', 'discussion_threads', 'compaq', 'inbox', 'sec_panel'] 0
# data/maildir/lay-k/elizabeth [] 35
# data/maildir/lay-k/sent_items [] 13
# data/maildir/lay-k/business [] 2
# data/maildir/lay-k/family [] 8
# data/maildir/lay-k/all_documents [] 1127
# data/maildir/lay-k/deleted_items [] 1126
# data/maildir/lay-k/_sent [] 261
# data/maildir/lay-k/calendar [] 8
# data/maildir/lay-k/notes_inbox [] 799
# data/maildir/lay-k/sent [] 266
# data/maildir/lay-k/enron [] 5
# data/maildir/lay-k/discussion_threads [] 910
# data/maildir/lay-k/compaq [] 1
# data/maildir/lay-k/inbox [] 1373
# data/maildir/lay-k/sec_panel [] 3
# data/maildir/slinger-r ['sent_items', 'deleted_items', 'inbox'] 0
# data/maildir/slinger-r/sent_items [] 48
# data/maildir/slinger-r/deleted_items [] 35
# data/maildir/slinger-r/inbox [] 49
# data/maildir/arnold-j ['active_international', 'bristol_babcock', 'avaya', 'bmc', 'dell', 'sonoco', 'universal_studios', 'ge', 'computer_associates', 'weekly_report', 'enron_europe', 'fedex', 'cooper_cameron', 'sent_items', 'colleen_koenig', 'ebs', '_sent_mail', 'all_documents', 'deleted_items', 'sony', 'oec', 'purchasing', 'ees', 'hp', 'tasks', 'human_resources', 'vulcan_signs', 'continental_airlines', 'pcc_values', 'sarah_joy_hunter', 'corestaff', 'notes_inbox', 'sent', 'personal', 'discussion_threads', 'sparefinders_com', '2000_conference', 'sap', 'compaq', 'nepco', 'kinko_s', 'nepco_europe', 'inbox', 'requisite', 'bridge', 'etol'] 0
# data/maildir/arnold-j/active_international [] 1
# data/maildir/arnold-j/bristol_babcock [] 2
# data/maildir/arnold-j/avaya [] 5
# data/maildir/arnold-j/bmc [] 16
# data/maildir/arnold-j/dell [] 1
# data/maildir/arnold-j/sonoco [] 1
# data/maildir/arnold-j/universal_studios [] 8
# data/maildir/arnold-j/ge [] 1
# data/maildir/arnold-j/computer_associates [] 1
# data/maildir/arnold-j/weekly_report [] 1
# data/maildir/arnold-j/enron_europe [] 1
# data/maildir/arnold-j/fedex [] 6
# data/maildir/arnold-j/cooper_cameron [] 1
# data/maildir/arnold-j/sent_items [] 723
# data/maildir/arnold-j/colleen_koenig [] 2
# data/maildir/arnold-j/ebs [] 3
# data/maildir/arnold-j/_sent_mail [] 814
# data/maildir/arnold-j/all_documents [] 1047
# data/maildir/arnold-j/deleted_items [] 723
# data/maildir/arnold-j/sony [] 6
# data/maildir/arnold-j/oec [] 1
# data/maildir/arnold-j/purchasing [] 1
# data/maildir/arnold-j/ees [] 1
# data/maildir/arnold-j/hp [] 13
# data/maildir/arnold-j/tasks [] 14
# data/maildir/arnold-j/human_resources [] 1
# data/maildir/arnold-j/vulcan_signs [] 3
# data/maildir/arnold-j/continental_airlines [] 12
# data/maildir/arnold-j/pcc_values [] 2
# data/maildir/arnold-j/sarah_joy_hunter [] 1
# data/maildir/arnold-j/corestaff [] 2
# data/maildir/arnold-j/notes_inbox [] 84
# data/maildir/arnold-j/sent [] 816
# data/maildir/arnold-j/personal [] 5
# data/maildir/arnold-j/discussion_threads [] 401
# data/maildir/arnold-j/sparefinders_com [] 1
# data/maildir/arnold-j/2000_conference [] 3
# data/maildir/arnold-j/sap [] 3
# data/maildir/arnold-j/compaq [] 13
# data/maildir/arnold-j/nepco [] 1
# data/maildir/arnold-j/kinko_s [] 4
# data/maildir/arnold-j/nepco_europe [] 2
# data/maildir/arnold-j/inbox [] 142
# data/maildir/arnold-j/requisite [] 4
# data/maildir/arnold-j/bridge [] 2
# data/maildir/arnold-j/etol [] 3
# data/maildir/saibi-e ['sent_items', 'all_documents', 'deleted_items', 'calendar', 'saved', 'notes_inbox', 'discussion_threads', 'inbox'] 0
# data/maildir/saibi-e/sent_items [] 39
# data/maildir/saibi-e/all_documents [] 13
# data/maildir/saibi-e/deleted_items [] 16
# data/maildir/saibi-e/calendar [] 6
# data/maildir/saibi-e/saved [] 19
# data/maildir/saibi-e/notes_inbox [] 2
# data/maildir/saibi-e/discussion_threads [] 13
# data/maildir/saibi-e/inbox [] 1008
# data/maildir/mckay-j ['ubs_warburg', 'perfmgmt', 'sent_items', 'pipeinfo', 'ubswenergy_com', 'contacts', 'deleted_items', 'to_do', 'recuriting', 'tasks', 'ne_development', 'retail', 'calendar', 'personal', 'enron', 'quotes', 'pipeline_info', 'inbox'] 0
# data/maildir/mckay-j/ubs_warburg [] 23
# data/maildir/mckay-j/perfmgmt [] 18
# data/maildir/mckay-j/sent_items [] 296
# data/maildir/mckay-j/pipeinfo [] 13
# data/maildir/mckay-j/ubswenergy_com [] 30
# data/maildir/mckay-j/contacts [] 2
# data/maildir/mckay-j/deleted_items [] 241
# data/maildir/mckay-j/to_do [] 3
# data/maildir/mckay-j/recuriting [] 3
# data/maildir/mckay-j/tasks [] 4
# data/maildir/mckay-j/ne_development [] 3
# data/maildir/mckay-j/retail [] 74
# data/maildir/mckay-j/calendar [] 3
# data/maildir/mckay-j/personal [] 103
# data/maildir/mckay-j/enron [] 43
# data/maildir/mckay-j/quotes ['not_printed'] 65
# data/maildir/mckay-j/quotes/not_printed [] 5
# data/maildir/mckay-j/pipeline_info [] 43
# data/maildir/mckay-j/inbox [] 26
# data/maildir/kitchen-l ['sent_items', 'contacts', 'deleted_items', 'tasks', 'outbox', 'calendar', 'inbox', '_americas'] 0
# data/maildir/kitchen-l/sent_items [] 1132
# data/maildir/kitchen-l/contacts [] 3
# data/maildir/kitchen-l/deleted_items [] 202
# data/maildir/kitchen-l/tasks [] 1
# data/maildir/kitchen-l/outbox [] 1
# data/maildir/kitchen-l/calendar [] 39
# data/maildir/kitchen-l/inbox ['press'] 140
# data/maildir/kitchen-l/inbox/press [] 7
# data/maildir/kitchen-l/_americas ['netco_credit', 'eol', 'it', 'netco_restart', 'netco_eol', 'vp_prc', 'board', 'tech_services', 'sec_media', 'regulatory', 'portland', 'data_room', 'netco_legal', 'south_america', 'mrha', 'legal', 'tammie', 'bridgeline', 'julie', 'ees', 'netco_it', 'east_power', 'press', 'eim', 'netco_canada', 'europe', 'netco_reg', 'ooc', 'sec', 'hr', 'rac', 'netco_hr', 'canada', 'asset_marketing', 'netco_portland', 'earnings', 'netco_agreements', 'business_plans', 'restructuring', 'tax', 'mexico', 'esvl', 'hpl', 'finance', 'culture', 'turbines', 'press1', 'gas', 'netco_estate'] 0
# data/maildir/kitchen-l/_americas/netco_credit [] 12
# data/maildir/kitchen-l/_americas/eol [] 171
# data/maildir/kitchen-l/_americas/it [] 149
# data/maildir/kitchen-l/_americas/netco_restart [] 61
# data/maildir/kitchen-l/_americas/netco_eol [] 91
# data/maildir/kitchen-l/_americas/vp_prc [] 9
# data/maildir/kitchen-l/_americas/board [] 34
# data/maildir/kitchen-l/_americas/tech_services [] 21
# data/maildir/kitchen-l/_americas/sec_media [] 84
# data/maildir/kitchen-l/_americas/regulatory [] 242
# data/maildir/kitchen-l/_americas/portland [] 203
# data/maildir/kitchen-l/_americas/data_room [] 1
# data/maildir/kitchen-l/_americas/netco_legal [] 48
# data/maildir/kitchen-l/_americas/south_america [] 17
# data/maildir/kitchen-l/_americas/mrha ['ooc'] 82
# data/maildir/kitchen-l/_americas/mrha/ooc [] 309
# data/maildir/kitchen-l/_americas/legal [] 21
# data/maildir/kitchen-l/_americas/tammie [] 50
# data/maildir/kitchen-l/_americas/bridgeline [] 5
# data/maildir/kitchen-l/_americas/julie [] 7
# data/maildir/kitchen-l/_americas/ees [] 25
# data/maildir/kitchen-l/_americas/netco_it [] 11
# data/maildir/kitchen-l/_americas/east_power [] 257
# data/maildir/kitchen-l/_americas/press [] 61
# data/maildir/kitchen-l/_americas/eim [] 2
# data/maildir/kitchen-l/_americas/netco_canada [] 12
# data/maildir/kitchen-l/_americas/europe [] 8
# data/maildir/kitchen-l/_americas/netco_reg [] 16
# data/maildir/kitchen-l/_americas/ooc [] 202
# data/maildir/kitchen-l/_americas/sec [] 30
# data/maildir/kitchen-l/_americas/hr [] 306
# data/maildir/kitchen-l/_americas/rac [] 16
# data/maildir/kitchen-l/_americas/netco_hr [] 82
# data/maildir/kitchen-l/_americas/canada [] 13
# data/maildir/kitchen-l/_americas/asset_marketing [] 103
# data/maildir/kitchen-l/_americas/netco_portland [] 5
# data/maildir/kitchen-l/_americas/earnings [] 12
# data/maildir/kitchen-l/_americas/netco_agreements [] 2
# data/maildir/kitchen-l/_americas/business_plans [] 58
# data/maildir/kitchen-l/_americas/restructuring [] 49
# data/maildir/kitchen-l/_americas/tax [] 6
# data/maildir/kitchen-l/_americas/mexico [] 96
# data/maildir/kitchen-l/_americas/esvl [] 715
# data/maildir/kitchen-l/_americas/hpl [] 37
# data/maildir/kitchen-l/_americas/finance [] 68
# data/maildir/kitchen-l/_americas/culture [] 27
# data/maildir/kitchen-l/_americas/turbines ['trading'] 83
# data/maildir/kitchen-l/_americas/turbines/trading [] 7
# data/maildir/kitchen-l/_americas/press1 [] 7
# data/maildir/kitchen-l/_americas/gas [] 87
# data/maildir/kitchen-l/_americas/netco_estate [] 1
# data/maildir/mims-thurston-p ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'calendar', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/mims-thurston-p/sent_items [] 229
# data/maildir/mims-thurston-p/_sent_mail [] 237
# data/maildir/mims-thurston-p/all_documents [] 215
# data/maildir/mims-thurston-p/deleted_items [] 715
# data/maildir/mims-thurston-p/calendar [] 10
# data/maildir/mims-thurston-p/sent [] 209
# data/maildir/mims-thurston-p/discussion_threads [] 75
# data/maildir/mims-thurston-p/inbox [] 348
# data/maildir/king-j ['private_folders', 'sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'parking', 'calendar', 'notes_inbox', 'sent', 'personal', 'discussion_threads', 'inbox'] 0
# data/maildir/king-j/private_folders ['personal'] 0
# data/maildir/king-j/private_folders/personal [] 4
# data/maildir/king-j/sent_items [] 13
# data/maildir/king-j/_sent_mail [] 3
# data/maildir/king-j/all_documents [] 17
# data/maildir/king-j/deleted_items [] 346
# data/maildir/king-j/parking [] 1
# data/maildir/king-j/calendar [] 5
# data/maildir/king-j/notes_inbox [] 10
# data/maildir/king-j/sent [] 3
# data/maildir/king-j/personal [] 7
# data/maildir/king-j/discussion_threads [] 16
# data/maildir/king-j/inbox [] 37
# data/maildir/harris-s ['deleted_items', 'inbox'] 0
# data/maildir/harris-s/deleted_items [] 492
# data/maildir/harris-s/inbox [] 56
# data/maildir/storey-g ['fundies', 'it', 'estate', 'ring_trades', 'sent_items', 'govt', '_sent_mail', 'drafts', 'all_documents', 'deleted_items', 'tcpl', 'calendar', 'netco', 'canada', 'central', 'credit_rings', 'personal', 'discussion_threads', 'inbox'] 0
# data/maildir/storey-g/fundies [] 1
# data/maildir/storey-g/it [] 86
# data/maildir/storey-g/estate [] 18
# data/maildir/storey-g/ring_trades [] 15
# data/maildir/storey-g/sent_items [] 138
# data/maildir/storey-g/govt [] 15
# data/maildir/storey-g/_sent_mail [] 13
# data/maildir/storey-g/drafts [] 1
# data/maildir/storey-g/all_documents [] 68
# data/maildir/storey-g/deleted_items [] 327
# data/maildir/storey-g/tcpl [] 24
# data/maildir/storey-g/calendar [] 7
# data/maildir/storey-g/netco [] 22
# data/maildir/storey-g/canada [] 1
# data/maildir/storey-g/central [] 19
# data/maildir/storey-g/credit_rings [] 9
# data/maildir/storey-g/personal [] 65
# data/maildir/storey-g/discussion_threads [] 65
# data/maildir/storey-g/inbox [] 133
# data/maildir/horton-s ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/horton-s/sent_items [] 152
# data/maildir/horton-s/_sent_mail [] 291
# data/maildir/horton-s/all_documents [] 713
# data/maildir/horton-s/deleted_items ['_sent_mail'] 391
# data/maildir/horton-s/deleted_items/_sent_mail [] 88
# data/maildir/horton-s/notes_inbox [] 22
# data/maildir/horton-s/sent [] 291
# data/maildir/horton-s/discussion_threads [] 449
# data/maildir/horton-s/inbox [] 73
# data/maildir/love-p ['other', 'ontario', 'sent_items', '_sent_mail', 'accomplish', 'all_documents', 'deleted_items', 'to_do', 'central_desk_class_regis_', 'ontario_oa', 'tasks', 'calendar', 'risk_management', 'notes_inbox', 'sent', 'west', 'central', 'personal', 'discussion_threads', 'inbox', 'east_desk'] 0
# data/maildir/love-p/other [] 3
# data/maildir/love-p/ontario [] 2
# data/maildir/love-p/sent_items [] 599
# data/maildir/love-p/_sent_mail [] 886
# data/maildir/love-p/accomplish [] 10
# data/maildir/love-p/all_documents [] 1035
# data/maildir/love-p/deleted_items [] 488
# data/maildir/love-p/to_do [] 2
# data/maildir/love-p/central_desk_class_regis_ [] 3
# data/maildir/love-p/ontario_oa [] 2
# data/maildir/love-p/tasks [] 1
# data/maildir/love-p/calendar [] 14
# data/maildir/love-p/risk_management [] 20
# data/maildir/love-p/notes_inbox [] 49
# data/maildir/love-p/sent [] 886
# data/maildir/love-p/west [] 12
# data/maildir/love-p/central [] 123
# data/maildir/love-p/personal [] 104
# data/maildir/love-p/discussion_threads [] 578
# data/maildir/love-p/inbox [] 151
# data/maildir/love-p/east_desk [] 34
# data/maildir/benson-r ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'calendar', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/benson-r/sent_items [] 16
# data/maildir/benson-r/_sent_mail [] 9
# data/maildir/benson-r/all_documents [] 84
# data/maildir/benson-r/deleted_items [] 203
# data/maildir/benson-r/calendar [] 6
# data/maildir/benson-r/notes_inbox [] 75
# data/maildir/benson-r/sent [] 7
# data/maildir/benson-r/discussion_threads [] 77
# data/maildir/benson-r/inbox ['large_messages'] 274
# data/maildir/benson-r/inbox/large_messages [] 16
# data/maildir/schwieger-j ['bammel_stg', 'sent_items', 'all_documents', 'deleted_items', 'hpl_sell', 'outbox', 'calendar', 'personal', 'discussion_threads', 'credit_issues', 'inbox'] 0
# data/maildir/schwieger-j/bammel_stg [] 30
# data/maildir/schwieger-j/sent_items [] 151
# data/maildir/schwieger-j/all_documents [] 85
# data/maildir/schwieger-j/deleted_items [] 200
# data/maildir/schwieger-j/hpl_sell [] 21
# data/maildir/schwieger-j/outbox [] 2
# data/maildir/schwieger-j/calendar [] 13
# data/maildir/schwieger-j/personal [] 110
# data/maildir/schwieger-j/discussion_threads [] 81
# data/maildir/schwieger-j/credit_issues [] 3
# data/maildir/schwieger-j/inbox [] 42
# data/maildir/crandell-s ['sent_items', 'deleted_items', 'to_do', 'calendar', 'inbox'] 0
# data/maildir/crandell-s/sent_items [] 149
# data/maildir/crandell-s/deleted_items [] 89
# data/maildir/crandell-s/to_do [] 1
# data/maildir/crandell-s/calendar [] 6
# data/maildir/crandell-s/inbox ['rto', 'regulatory', 'rto_west', 'ferc', 'bankruptcy', 'ubs'] 246
# data/maildir/crandell-s/inbox/rto [] 1
# data/maildir/crandell-s/inbox/regulatory [] 1
# data/maildir/crandell-s/inbox/rto_west [] 14
# data/maildir/crandell-s/inbox/ferc [] 1
# data/maildir/crandell-s/inbox/bankruptcy [] 10
# data/maildir/crandell-s/inbox/ubs [] 1
# data/maildir/mann-k ['florida', 'ema_s', 'chicago', 'sent_items', 'new_jersey_natural', 'power_purchase_eei', '_sent_mail', 'panda', 'contacts', 'haywood', 'all_documents', 'deleted_items', 'ge_general', 'nrg', 'tasks', 'yazoo_city', 'midway', 'blue_dog', 'lm6000', 'vepco', 'general_stuff', 'off_balance_sheet_form_contracts', 'policy_manual_and_united_way', 'notes_inbox', 'sent', 'enovate', 'nimo', 'discussion_threads', 'asset_management_documents', 'coral', 'co_op_city', 'westinghouse', 'fuel_cells', 'inbox'] 0
# data/maildir/mann-k/florida [] 59
# data/maildir/mann-k/ema_s [] 5
# data/maildir/mann-k/chicago [] 87
# data/maildir/mann-k/sent_items [] 266
# data/maildir/mann-k/new_jersey_natural [] 3
# data/maildir/mann-k/power_purchase_eei [] 6
# data/maildir/mann-k/_sent_mail [] 4220
# data/maildir/mann-k/panda [] 107
# data/maildir/mann-k/contacts [] 5
# data/maildir/mann-k/haywood [] 20
# data/maildir/mann-k/all_documents [] 6647
# data/maildir/mann-k/deleted_items [] 180
# data/maildir/mann-k/ge_general [] 118
# data/maildir/mann-k/nrg [] 5
# data/maildir/mann-k/tasks [] 2
# data/maildir/mann-k/yazoo_city [] 186
# data/maildir/mann-k/midway [] 29
# data/maildir/mann-k/blue_dog [] 121
# data/maildir/mann-k/lm6000 [] 227
# data/maildir/mann-k/vepco [] 55
# data/maildir/mann-k/general_stuff [] 141
# data/maildir/mann-k/off_balance_sheet_form_contracts [] 76
# data/maildir/mann-k/policy_manual_and_united_way [] 7
# data/maildir/mann-k/notes_inbox [] 695
# data/maildir/mann-k/sent [] 4440
# data/maildir/mann-k/enovate [] 71
# data/maildir/mann-k/nimo [] 3
# data/maildir/mann-k/discussion_threads [] 4965
# data/maildir/mann-k/asset_management_documents [] 3
# data/maildir/mann-k/coral [] 107
# data/maildir/mann-k/co_op_city [] 23
# data/maildir/mann-k/westinghouse [] 63
# data/maildir/mann-k/fuel_cells [] 94
# data/maildir/mann-k/inbox [] 345
# data/maildir/haedicke-m ['powersystems', 'brazilian_arbitration', 'isda', 'budget', 'enron_net_works', 'sent_items', 'cuiaba', 'fuel', 'chinesewallspolicy', 'all_documents', 'deleted_items', 'art', 'eecc', 'organizationalchanges', 'tva', 'accomplishments', 'bear', 'arcor', 'municipalities', 'dabhol', 'cftc', 'newpowernoncompete', 'southamerica', 'lexisid', 'globalassets', 'mehpictures', 'california', 'sempre', 'albertappas', 'technologyplan', 'calendar', 'powercontracts', 'notes_inbox', 'sent', 'stanley', 'riskmemos', 'riskratings', 'japan', 'vitro', 'hpl', 'policies', 'inbox', 'toptenrisks', 'prc', 'performancematters', 'brazos_tenaska'] 0
# data/maildir/haedicke-m/powersystems [] 3
# data/maildir/haedicke-m/brazilian_arbitration [] 1
# data/maildir/haedicke-m/isda [] 9
# data/maildir/haedicke-m/budget [] 8
# data/maildir/haedicke-m/enron_net_works [] 1
# data/maildir/haedicke-m/sent_items [] 116
# data/maildir/haedicke-m/cuiaba [] 1
# data/maildir/haedicke-m/fuel [] 4
# data/maildir/haedicke-m/chinesewallspolicy [] 1
# data/maildir/haedicke-m/all_documents [] 2141
# data/maildir/haedicke-m/deleted_items [] 262
# data/maildir/haedicke-m/art [] 1
# data/maildir/haedicke-m/eecc [] 1
# data/maildir/haedicke-m/organizationalchanges [] 4
# data/maildir/haedicke-m/tva [] 4
# data/maildir/haedicke-m/accomplishments [] 1
# data/maildir/haedicke-m/bear [] 2
# data/maildir/haedicke-m/arcor [] 3
# data/maildir/haedicke-m/municipalities [] 1
# data/maildir/haedicke-m/dabhol [] 11
# data/maildir/haedicke-m/cftc [] 3
# data/maildir/haedicke-m/newpowernoncompete [] 2
# data/maildir/haedicke-m/southamerica [] 8
# data/maildir/haedicke-m/lexisid [] 2
# data/maildir/haedicke-m/globalassets [] 1
# data/maildir/haedicke-m/mehpictures [] 4
# data/maildir/haedicke-m/california [] 34
# data/maildir/haedicke-m/sempre [] 1
# data/maildir/haedicke-m/albertappas [] 2
# data/maildir/haedicke-m/technologyplan [] 1
# data/maildir/haedicke-m/calendar [] 41
# data/maildir/haedicke-m/powercontracts [] 1
# data/maildir/haedicke-m/notes_inbox [] 949
# data/maildir/haedicke-m/sent [] 988
# data/maildir/haedicke-m/stanley [] 5
# data/maildir/haedicke-m/riskmemos [] 3
# data/maildir/haedicke-m/riskratings [] 2
# data/maildir/haedicke-m/japan [] 1
# data/maildir/haedicke-m/vitro [] 5
# data/maildir/haedicke-m/hpl [] 1
# data/maildir/haedicke-m/policies [] 2
# data/maildir/haedicke-m/inbox ['pg_eplanofreorg', 'msu', 'ees_products', '360network', 'negctc'] 600
# data/maildir/haedicke-m/inbox/pg_eplanofreorg [] 1
# data/maildir/haedicke-m/inbox/msu [] 1
# data/maildir/haedicke-m/inbox/ees_products ['directaccess'] 1
# data/maildir/haedicke-m/inbox/ees_products/directaccess [] 2
# data/maildir/haedicke-m/inbox/360network [] 2
# data/maildir/haedicke-m/inbox/negctc [] 1
# data/maildir/haedicke-m/toptenrisks [] 4
# data/maildir/haedicke-m/prc [] 1
# data/maildir/haedicke-m/performancematters [] 1
# data/maildir/haedicke-m/brazos_tenaska [] 1
# data/maildir/allen-p ['straw', 'sent_items', '_sent_mail', 'contacts', 'all_documents', 'deleted_items', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/allen-p/straw [] 8
# data/maildir/allen-p/sent_items [] 345
# data/maildir/allen-p/_sent_mail [] 602
# data/maildir/allen-p/contacts [] 2
# data/maildir/allen-p/all_documents [] 628
# data/maildir/allen-p/deleted_items [] 361
# data/maildir/allen-p/notes_inbox [] 48
# data/maildir/allen-p/sent [] 562
# data/maildir/allen-p/discussion_threads [] 412
# data/maildir/allen-p/inbox [] 66
# data/maildir/staab-t ['mark_whitt', 'crestone', 'post_bankruptcy', 'sent_items', 'psco', 'deleted_items', 'lost_creek', 'unify', 'tasks', 'citizens', 'to_do_list', 'accounting_issues', 'corporate', 'contract_bids', 'personal', 'desert_power', 'inbox'] 0
# data/maildir/staab-t/mark_whitt [] 6
# data/maildir/staab-t/crestone [] 14
# data/maildir/staab-t/post_bankruptcy [] 6
# data/maildir/staab-t/sent_items [] 96
# data/maildir/staab-t/psco [] 8
# data/maildir/staab-t/deleted_items [] 284
# data/maildir/staab-t/lost_creek [] 10
# data/maildir/staab-t/unify [] 5
# data/maildir/staab-t/tasks [] 2
# data/maildir/staab-t/citizens [] 21
# data/maildir/staab-t/to_do_list [] 17
# data/maildir/staab-t/accounting_issues [] 3
# data/maildir/staab-t/corporate [] 14
# data/maildir/staab-t/contract_bids [] 14
# data/maildir/staab-t/personal [] 28
# data/maildir/staab-t/desert_power [] 3
# data/maildir/staab-t/inbox [] 90
# data/maildir/stokley-c ['chris_stokley'] 0
# data/maildir/stokley-c/chris_stokley ['murray', 'mid_markt', 'regulatory', 'projects', 'enron_corp', 'iso', 'volume_mang_', 'sent'] 0
# data/maildir/stokley-c/chris_stokley/murray [] 75
# data/maildir/stokley-c/chris_stokley/mid_markt [] 33
# data/maildir/stokley-c/chris_stokley/regulatory [] 13
# data/maildir/stokley-c/chris_stokley/projects ['ees', 'sqmd', 'ees_'] 0
# data/maildir/stokley-c/chris_stokley/projects/ees [] 4
# data/maildir/stokley-c/chris_stokley/projects/sqmd [] 33
# data/maildir/stokley-c/chris_stokley/projects/ees_ ['info', 'banding', 'brenda_herod', 'todd_busby', 'metering_and_forcasting', 'intr_month_book', 'ercot', 'neil_b_'] 0
# data/maildir/stokley-c/chris_stokley/projects/ees_/info [] 14
# data/maildir/stokley-c/chris_stokley/projects/ees_/banding ['kpmg'] 12
# data/maildir/stokley-c/chris_stokley/projects/ees_/banding/kpmg [] 40
# data/maildir/stokley-c/chris_stokley/projects/ees_/brenda_herod [] 6
# data/maildir/stokley-c/chris_stokley/projects/ees_/todd_busby [] 2
# data/maildir/stokley-c/chris_stokley/projects/ees_/metering_and_forcasting [] 27
# data/maildir/stokley-c/chris_stokley/projects/ees_/intr_month_book [] 6
# data/maildir/stokley-c/chris_stokley/projects/ees_/ercot [] 11
# data/maildir/stokley-c/chris_stokley/projects/ees_/neil_b_ [] 20
# data/maildir/stokley-c/chris_stokley/enron_corp [] 19
# data/maildir/stokley-c/chris_stokley/iso ['info', 'mrkt_info', 'client_rep'] 0
# data/maildir/stokley-c/chris_stokley/iso/info [] 29
# data/maildir/stokley-c/chris_stokley/iso/mrkt_info [] 125
# data/maildir/stokley-c/chris_stokley/iso/client_rep [] 45
# data/maildir/stokley-c/chris_stokley/volume_mang_ [] 223
# data/maildir/stokley-c/chris_stokley/sent [] 515
# data/maildir/lavorato-j ['var', 'sent_items', 'systems', 'offsite', '_sent_mail', 'all_documents', 'deleted_items', 'powerwest', 'to_do', 'comp', 'ecr', 'southamerica', 'coal', 'california', 'calendar', 'transport', 'notes_inbox', 'sent', 'canada', 'weather', 'phone_numbers', 'powereast', 'personal', 'controls', 'discussion_threads', 'jean', 'pulp', '_hedgefunds', 'old_inbox', 'inbox', 'prc', 'analyst_associate', 'gas'] 0
# data/maildir/lavorato-j/var [] 1
# data/maildir/lavorato-j/sent_items [] 674
# data/maildir/lavorato-j/systems [] 3
# data/maildir/lavorato-j/offsite [] 15
# data/maildir/lavorato-j/_sent_mail [] 544
# data/maildir/lavorato-j/all_documents [] 853
# data/maildir/lavorato-j/deleted_items [] 715
# data/maildir/lavorato-j/powerwest [] 11
# data/maildir/lavorato-j/to_do [] 6
# data/maildir/lavorato-j/comp [] 6
# data/maildir/lavorato-j/ecr [] 1
# data/maildir/lavorato-j/southamerica [] 10
# data/maildir/lavorato-j/coal [] 2
# data/maildir/lavorato-j/california [] 17
# data/maildir/lavorato-j/calendar [] 167
# data/maildir/lavorato-j/transport [] 1
# data/maildir/lavorato-j/notes_inbox [] 57
# data/maildir/lavorato-j/sent [] 650
# data/maildir/lavorato-j/canada [] 2
# data/maildir/lavorato-j/weather [] 4
# data/maildir/lavorato-j/phone_numbers [] 5
# data/maildir/lavorato-j/powereast [] 12
# data/maildir/lavorato-j/personal [] 72
# data/maildir/lavorato-j/controls [] 6
# data/maildir/lavorato-j/discussion_threads [] 416
# data/maildir/lavorato-j/jean [] 6
# data/maildir/lavorato-j/pulp [] 2
# data/maildir/lavorato-j/_hedgefunds [] 2
# data/maildir/lavorato-j/old_inbox [] 120
# data/maildir/lavorato-j/inbox [] 277
# data/maildir/lavorato-j/prc [] 2
# data/maildir/lavorato-j/analyst_associate [] 24
# data/maildir/lavorato-j/gas [] 2
# data/maildir/shankman-j ['sent_items', 'global_mkts', 'bks', 'saved_mail', 'all_documents', 'deleted_items', 'calendar', 'sent', 'personal', 'discussion_threads', 'old_email', 'inbox'] 0
# data/maildir/shankman-j/sent_items [] 59
# data/maildir/shankman-j/global_mkts [] 9
# data/maildir/shankman-j/bks [] 2
# data/maildir/shankman-j/saved_mail [] 27
# data/maildir/shankman-j/all_documents [] 1084
# data/maildir/shankman-j/deleted_items [] 841
# data/maildir/shankman-j/calendar [] 17
# data/maildir/shankman-j/sent [] 1025
# data/maildir/shankman-j/personal [] 33
# data/maildir/shankman-j/discussion_threads [] 549
# data/maildir/shankman-j/old_email [] 64
# data/maildir/shankman-j/inbox ['art_comm'] 129
# data/maildir/shankman-j/inbox/art_comm [] 17
# data/maildir/martin-t ['tom_s_docs', 'sent_items', '_sent_mail', 'contacts', 'all_documents', 'deleted_items', 'calendar', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/martin-t/tom_s_docs [] 18
# data/maildir/martin-t/sent_items [] 229
# data/maildir/martin-t/_sent_mail [] 23
# data/maildir/martin-t/contacts [] 8
# data/maildir/martin-t/all_documents [] 65
# data/maildir/martin-t/deleted_items [] 205
# data/maildir/martin-t/calendar [] 38
# data/maildir/martin-t/sent [] 1
# data/maildir/martin-t/discussion_threads [] 60
# data/maildir/martin-t/inbox [] 465
# data/maildir/whalley-l ['connect_deletes', '_sent_mail', 'contacts', 'all_documents', 'ecommerce', 'tasks', 'notes_inbox', 'sent', 'discussion_threads'] 0
# data/maildir/whalley-l/connect_deletes [] 172
# data/maildir/whalley-l/_sent_mail [] 219
# data/maildir/whalley-l/contacts [] 7
# data/maildir/whalley-l/all_documents [] 1083
# data/maildir/whalley-l/ecommerce [] 7
# data/maildir/whalley-l/tasks [] 3
# data/maildir/whalley-l/notes_inbox [] 650
# data/maildir/whalley-l/sent [] 233
# data/maildir/whalley-l/discussion_threads [] 961
# data/maildir/weldon-c ['eol', 'kern', 'citibank', 'it', 'private_folders', 'project_orange', 'training', 'sent_items', 'ed', 'rotation_1', 'lng', '_sent_mail', 'contacts', 'unocal', 'all_documents', 'deleted_items', 'highland', 'abraxas', 'misc__gas_issues', 'associate', 'freestone', 'neumin', 'midway', 'calendar', 'national_fuel', 'friends', 'sent', 'ut_mba', 'ft__pierce', 'stagecoach', 'discussion_threads', 'austin_energy', 'kcs', 'southern_lng', 'inbox', 'prc', 'misc_'] 0
# data/maildir/weldon-c/eol [] 6
# data/maildir/weldon-c/kern [] 7
# data/maildir/weldon-c/citibank [] 9
# data/maildir/weldon-c/it [] 10
# data/maildir/weldon-c/private_folders ['associate'] 0
# data/maildir/weldon-c/private_folders/associate [] 5
# data/maildir/weldon-c/project_orange [] 2
# data/maildir/weldon-c/training [] 7
# data/maildir/weldon-c/sent_items [] 190
# data/maildir/weldon-c/ed [] 2
# data/maildir/weldon-c/rotation_1 ['hurricane', 'water', 'ja'] 0
# data/maildir/weldon-c/rotation_1/hurricane [] 4
# data/maildir/weldon-c/rotation_1/water ['ag_model'] 0
# data/maildir/weldon-c/rotation_1/water/ag_model [] 3
# data/maildir/weldon-c/rotation_1/ja [] 1
# data/maildir/weldon-c/lng [] 2
# data/maildir/weldon-c/_sent_mail [] 82
# data/maildir/weldon-c/contacts [] 1
# data/maildir/weldon-c/unocal [] 2
# data/maildir/weldon-c/all_documents [] 304
# data/maildir/weldon-c/deleted_items [] 271
# data/maildir/weldon-c/highland [] 6
# data/maildir/weldon-c/abraxas [] 2
# data/maildir/weldon-c/misc__gas_issues [] 11
# data/maildir/weldon-c/associate [] 6
# data/maildir/weldon-c/freestone [] 2
# data/maildir/weldon-c/neumin [] 5
# data/maildir/weldon-c/midway [] 2
# data/maildir/weldon-c/calendar [] 3
# data/maildir/weldon-c/national_fuel [] 6
# data/maildir/weldon-c/friends [] 14
# data/maildir/weldon-c/sent [] 184
# data/maildir/weldon-c/ut_mba [] 15
# data/maildir/weldon-c/ft__pierce [] 64
# data/maildir/weldon-c/stagecoach [] 13
# data/maildir/weldon-c/discussion_threads [] 199
# data/maildir/weldon-c/austin_energy [] 3
# data/maildir/weldon-c/kcs [] 25
# data/maildir/weldon-c/southern_lng [] 6
# data/maildir/weldon-c/inbox ['ubs', 'trading'] 41
# data/maildir/weldon-c/inbox/ubs [] 2
# data/maildir/weldon-c/inbox/trading [] 4
# data/maildir/weldon-c/prc [] 2
# data/maildir/weldon-c/misc_ [] 43
# data/maildir/quigley-d ['ina', 'private_folders', 'sent_items', 'fin_desk', 'deleted_items', 'carr', '_exchange', '_exchange_pos', 'bmr', 'calendar', 'mid_market', '_exchange_info', 'myfriends', 'inbox', 'prc'] 0
# data/maildir/quigley-d/ina [] 21
# data/maildir/quigley-d/private_folders ['ffl', 'kq___dq'] 0
# data/maildir/quigley-d/private_folders/ffl [] 52
# data/maildir/quigley-d/private_folders/kq___dq [] 60
# data/maildir/quigley-d/sent_items [] 506
# data/maildir/quigley-d/fin_desk [] 43
# data/maildir/quigley-d/deleted_items [] 390
# data/maildir/quigley-d/carr [] 29
# data/maildir/quigley-d/_exchange [] 32
# data/maildir/quigley-d/_exchange_pos [] 45
# data/maildir/quigley-d/bmr [] 37
# data/maildir/quigley-d/calendar [] 6
# data/maildir/quigley-d/mid_market [] 4
# data/maildir/quigley-d/_exchange_info [] 94
# data/maildir/quigley-d/myfriends [] 146
# data/maildir/quigley-d/inbox [] 102
# data/maildir/quigley-d/prc [] 1
# data/maildir/shively-h ['peoples_hedges', 'sent_items', '_sent_mail', 'contacts', 'all_documents', 'deleted_items', 'to_do', 'tasks', 'calendar', 'sent', 'discussion_threads', 'misc', 'inbox', 'prc'] 2
# data/maildir/shively-h/peoples_hedges [] 7
# data/maildir/shively-h/sent_items [] 128
# data/maildir/shively-h/_sent_mail [] 282
# data/maildir/shively-h/contacts [] 17
# data/maildir/shively-h/all_documents [] 296
# data/maildir/shively-h/deleted_items [] 596
# data/maildir/shively-h/to_do [] 5
# data/maildir/shively-h/tasks [] 4
# data/maildir/shively-h/calendar [] 21
# data/maildir/shively-h/sent [] 273
# data/maildir/shively-h/discussion_threads [] 195
# data/maildir/shively-h/misc [] 20
# data/maildir/shively-h/inbox [] 143
# data/maildir/shively-h/prc [] 2
# data/maildir/dean-c ['info', 'sent_items', '_sent_mail', 'info2', 'all_documents', 'deleted_items', 'notes_inbox', 'sent', 'discussion_threads', 'info3', 'inbox'] 0
# data/maildir/dean-c/info [] 233
# data/maildir/dean-c/sent_items [] 33
# data/maildir/dean-c/_sent_mail [] 6
# data/maildir/dean-c/info2 [] 3
# data/maildir/dean-c/all_documents [] 327
# data/maildir/dean-c/deleted_items [] 343
# data/maildir/dean-c/notes_inbox [] 164
# data/maildir/dean-c/sent [] 5
# data/maildir/dean-c/discussion_threads [] 313
# data/maildir/dean-c/info3 [] 31
# data/maildir/dean-c/inbox [] 971
# data/maildir/white-s ['off_site', 'passwords', 'sent_items', 'curves', 'genco_plant_misc', 'ena_cal', 'contacts', 'all_documents', 'south_america', 'deleted_items', 'legal', 'press', 'tasks', 'services', 'flash', 'itinerary_receipt', 'doorstep', 'cya', 'teco', 'calendar', 'sent', 'global_standards', 'meetings', 'personal', 'personnel', 'discussion_threads', 'andersen_requests', 'portcalc_requests', 'val', 'west_var', 'inbox'] 0
# data/maildir/white-s/off_site [] 4
# data/maildir/white-s/passwords [] 3
# data/maildir/white-s/sent_items [] 445
# data/maildir/white-s/curves [] 2
# data/maildir/white-s/genco_plant_misc [] 2
# data/maildir/white-s/ena_cal [] 6
# data/maildir/white-s/contacts [] 6
# data/maildir/white-s/all_documents [] 176
# data/maildir/white-s/south_america [] 13
# data/maildir/white-s/deleted_items [] 989
# data/maildir/white-s/legal [] 29
# data/maildir/white-s/press [] 1
# data/maildir/white-s/tasks [] 3
# data/maildir/white-s/services [] 2
# data/maildir/white-s/flash ['200106'] 1
# data/maildir/white-s/flash/200106 [] 6
# data/maildir/white-s/itinerary_receipt [] 8
# data/maildir/white-s/doorstep [] 21
# data/maildir/white-s/cya [] 30
# data/maildir/white-s/teco [] 4
# data/maildir/white-s/calendar [] 143
# data/maildir/white-s/sent [] 12
# data/maildir/white-s/global_standards [] 12
# data/maildir/white-s/meetings [] 738
# data/maildir/white-s/personal [] 21
# data/maildir/white-s/personnel ['training', 'vacation'] 8
# data/maildir/white-s/personnel/training [] 1
# data/maildir/white-s/personnel/vacation [] 1
# data/maildir/white-s/discussion_threads [] 169
# data/maildir/white-s/andersen_requests [] 18
# data/maildir/white-s/portcalc_requests [] 1
# data/maildir/white-s/val [] 9
# data/maildir/white-s/west_var [] 1
# data/maildir/white-s/inbox [] 387
# data/maildir/quenet-j ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/quenet-j/sent_items [] 6
# data/maildir/quenet-j/_sent_mail [] 68
# data/maildir/quenet-j/all_documents [] 74
# data/maildir/quenet-j/deleted_items [] 136
# data/maildir/quenet-j/notes_inbox [] 6
# data/maildir/quenet-j/sent [] 68
# data/maildir/quenet-j/discussion_threads [] 24
# data/maildir/quenet-j/inbox [] 13
# data/maildir/merriss-s ['_sent_mail', 'all_documents', 'notes_inbox', 'discussion_threads'] 0
# data/maildir/merriss-s/_sent_mail [] 3
# data/maildir/merriss-s/all_documents [] 548
# data/maildir/merriss-s/notes_inbox [] 545
# data/maildir/merriss-s/discussion_threads [] 531
# data/maildir/mckay-b ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/mckay-b/sent_items [] 44
# data/maildir/mckay-b/_sent_mail [] 50
# data/maildir/mckay-b/all_documents [] 81
# data/maildir/mckay-b/deleted_items [] 308
# data/maildir/mckay-b/notes_inbox [] 24
# data/maildir/mckay-b/sent [] 50
# data/maildir/mckay-b/discussion_threads [] 38
# data/maildir/mckay-b/inbox [] 86
# data/maildir/gang-l ['sent_items', 'deleted_items', 'calendar', 'inbox'] 0
# data/maildir/gang-l/sent_items [] 90
# data/maildir/gang-l/deleted_items [] 451
# data/maildir/gang-l/calendar [] 1
# data/maildir/gang-l/inbox [] 48
# data/maildir/reitmeyer-j ['sent_items', 'deleted_items', 'inbox', 'jay_s_saved_stuff'] 0
# data/maildir/reitmeyer-j/sent_items [] 57
# data/maildir/reitmeyer-j/deleted_items [] 88
# data/maildir/reitmeyer-j/inbox [] 352
# data/maildir/reitmeyer-j/jay_s_saved_stuff [] 1
# data/maildir/germany-c ['eol', 'pending', 'notes', 'sent_items', 'calp_hopewell', 'book_issues', 'systems', 'appala', 'traderr_tools', '_sent_mail', 'contacts', 'all_documents', 'deleted_items', 'to_do', 'memos', 'ces_resolved', 'whatever', 'bankrupt', 'tasks', 'vng', 'takeover', 'ces_pending', 'calendar', 'transport', 'ces', 'notes_inbox', 'sent', 'personal', 'discussion_threads', 'new_power', 'sap', 'inbox', 'performance', 'insideferc', 'ogelthorpe'] 0
# data/maildir/germany-c/eol [] 2
# data/maildir/germany-c/pending [] 5
# data/maildir/germany-c/notes ['bankruptcy'] 0
# data/maildir/germany-c/notes/bankruptcy ['florida_issues'] 0
# data/maildir/germany-c/notes/bankruptcy/florida_issues [] 7
# data/maildir/germany-c/sent_items [] 1353
# data/maildir/germany-c/calp_hopewell [] 7
# data/maildir/germany-c/book_issues [] 7
# data/maildir/germany-c/systems [] 19
# data/maildir/germany-c/appala [] 104
# data/maildir/germany-c/traderr_tools [] 4
# data/maildir/germany-c/_sent_mail [] 1659
# data/maildir/germany-c/contacts [] 14
# data/maildir/germany-c/all_documents [] 3027
# data/maildir/germany-c/deleted_items [] 345
# data/maildir/germany-c/to_do [] 1
# data/maildir/germany-c/memos [] 46
# data/maildir/germany-c/ces_resolved [] 4
# data/maildir/germany-c/whatever [] 31
# data/maildir/germany-c/bankrupt ['cleburne_lone_star', 'juniper', 'sempra', 'bridgeline', 'enron_compressor_services', 'transport', 'reliant_entex', 'process', 'tdc_energy', 'enbridge', 'tall_dominion', 'aa____pending', 'midland_cogen'] 82
# data/maildir/germany-c/bankrupt/cleburne_lone_star [] 84
# data/maildir/germany-c/bankrupt/juniper [] 24
# data/maildir/germany-c/bankrupt/sempra [] 3
# data/maildir/germany-c/bankrupt/bridgeline [] 37
# data/maildir/germany-c/bankrupt/enron_compressor_services [] 14
# data/maildir/germany-c/bankrupt/transport ['trailblazer', 'northern_border', 'union_gas', 'password', 'transco', 'centana_storage', 'gulf_south', 'dominion', 'tennessee', 'iroquois', 'mrt', 'ngpl', 'columbia_gas_gulf', 'national_fuel', 'appalachain', 'colorado_intrastate', 'transwestern', 'el_paso', 'ena_upstream', 'sonat'] 47
# data/maildir/germany-c/bankrupt/transport/trailblazer [] 12
# data/maildir/germany-c/bankrupt/transport/northern_border [] 7
# data/maildir/germany-c/bankrupt/transport/union_gas [] 1
# data/maildir/germany-c/bankrupt/transport/password [] 2
# data/maildir/germany-c/bankrupt/transport/transco [] 3
# data/maildir/germany-c/bankrupt/transport/centana_storage [] 7
# data/maildir/germany-c/bankrupt/transport/gulf_south [] 1
# data/maildir/germany-c/bankrupt/transport/dominion [] 38
# data/maildir/germany-c/bankrupt/transport/tennessee [] 11
# data/maildir/germany-c/bankrupt/transport/iroquois [] 17
# data/maildir/germany-c/bankrupt/transport/mrt [] 6
# data/maildir/germany-c/bankrupt/transport/ngpl [] 1
# data/maildir/germany-c/bankrupt/transport/columbia_gas_gulf [] 14
# data/maildir/germany-c/bankrupt/transport/national_fuel [] 6
# data/maildir/germany-c/bankrupt/transport/appalachain [] 6
# data/maildir/germany-c/bankrupt/transport/colorado_intrastate [] 1
# data/maildir/germany-c/bankrupt/transport/transwestern [] 5
# data/maildir/germany-c/bankrupt/transport/el_paso [] 8
# data/maildir/germany-c/bankrupt/transport/ena_upstream [] 3
# data/maildir/germany-c/bankrupt/transport/sonat [] 16
# data/maildir/germany-c/bankrupt/reliant_entex [] 5
# data/maildir/germany-c/bankrupt/process [] 2
# data/maildir/germany-c/bankrupt/tdc_energy [] 5
# data/maildir/germany-c/bankrupt/enbridge [] 5
# data/maildir/germany-c/bankrupt/tall_dominion [] 45
# data/maildir/germany-c/bankrupt/aa____pending [] 1
# data/maildir/germany-c/bankrupt/midland_cogen [] 24
# data/maildir/germany-c/tasks [] 1
# data/maildir/germany-c/vng [] 20
# data/maildir/germany-c/takeover [] 5
# data/maildir/germany-c/ces_pending [] 1
# data/maildir/germany-c/calendar [] 19
# data/maildir/germany-c/transport [] 161
# data/maildir/germany-c/ces [] 390
# data/maildir/germany-c/notes_inbox [] 92
# data/maildir/germany-c/sent [] 2116
# data/maildir/germany-c/personal ['kingdom'] 57
# data/maildir/germany-c/personal/kingdom [] 5
# data/maildir/germany-c/discussion_threads [] 1992
# data/maildir/germany-c/new_power [] 54
# data/maildir/germany-c/sap [] 6
# data/maildir/germany-c/inbox [] 326
# data/maildir/germany-c/performance [] 3
# data/maildir/germany-c/insideferc [] 2
# data/maildir/germany-c/ogelthorpe [] 8
# data/maildir/presto-k ['presto_working_files', 'sent_items', 'all_documents', 'deleted_items', 'presto_files', 'junk_e_mail', 'calendar', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/presto-k/presto_working_files ['personnel_issues', 'ees_2_ways', 'assoc_analyst', 'personal_files', 'oneok', 'resumes'] 26
# ...
# data/maildir/steffes-j/security___collateral [] 28
# data/maildir/steffes-j/passwords [] 2
# data/maildir/steffes-j/eol [] 6
# data/maildir/steffes-j/ferc_reporting_reqts [] 1
# data/maildir/steffes-j/california_issues ['pnw_refunds', 'western_gas', 'ca_refunds'] 317
# data/maildir/steffes-j/california_issues/pnw_refunds [] 26
# data/maildir/steffes-j/california_issues/western_gas [] 15
# data/maildir/steffes-j/california_issues/ca_refunds [] 92
# data/maildir/steffes-j/wholesale_policy_reform [] 3
# data/maildir/steffes-j/notre_dame [] 10
# data/maildir/steffes-j/marketing_affiliate_matters [] 2
# data/maildir/steffes-j/ontario_nug [] 2
# data/maildir/steffes-j/rto [] 32
# data/maildir/steffes-j/important_information [] 4
# data/maildir/steffes-j/sent_items [] 1379
# data/maildir/steffes-j/caem [] 3
# data/maildir/steffes-j/midwest_retail_delivery [] 1
# data/maildir/steffes-j/alliance_rto [] 2
# data/maildir/steffes-j/ferc ['ferc_reporting_reqts', 'ferc_gas_issues', 'ferc_code_of_conduct_nopr', 'ferc_interconnection_anopr', 'ferc_west_infrastructure', 'ferc_mbr_proceeding', 'ferc_westconnect'] 2
# data/maildir/steffes-j/ferc/ferc_reporting_reqts [] 1
# data/maildir/steffes-j/ferc/ferc_gas_issues [] 1
# data/maildir/steffes-j/ferc/ferc_code_of_conduct_nopr [] 3
# data/maildir/steffes-j/ferc/ferc_interconnection_anopr [] 9
# data/maildir/steffes-j/ferc/ferc_west_infrastructure [] 2
# data/maildir/steffes-j/ferc/ferc_mbr_proceeding [] 4
# data/maildir/steffes-j/ferc/ferc_westconnect [] 1
# data/maildir/steffes-j/top_10_issues_6_1_01 [] 6
# data/maildir/steffes-j/contacts [] 1
# data/maildir/steffes-j/deleted_items [] 655
# data/maildir/steffes-j/to_do [] 24
# data/maildir/steffes-j/fed_legis_2001 [] 2
# data/maildir/steffes-j/pennsylvania [] 1
# data/maildir/steffes-j/tasks [] 1
# data/maildir/steffes-j/structured_supply [] 1
# data/maildir/steffes-j/spp [] 1
# data/maildir/steffes-j/cftc [] 5
# data/maildir/steffes-j/arizona [] 1
# data/maildir/steffes-j/electric_reports [] 2
# data/maildir/steffes-j/aga_storage_report [] 1
# data/maildir/steffes-j/texas [] 18
# data/maildir/steffes-j/ees_mgmt [] 18
# data/maildir/steffes-j/gas_issues [] 3
# data/maildir/steffes-j/competition_messages [] 1
# data/maildir/steffes-j/granite_ii [] 4
# data/maildir/steffes-j/nevada [] 4
# data/maildir/steffes-j/us_sup_ct_case [] 1
# data/maildir/steffes-j/eisb_ubr [] 1
# data/maildir/steffes-j/2001_mid_year_prc [] 7
# data/maildir/steffes-j/gu_recruiting [] 4
# data/maildir/steffes-j/congress [] 6
# data/maildir/steffes-j/bush_transition [] 1
# data/maildir/steffes-j/creditworthiness [] 3
# data/maildir/steffes-j/nat_gas [] 6
# data/maildir/steffes-j/environmental [] 1
# data/maildir/steffes-j/ga_fundamentals [] 2
# data/maildir/steffes-j/credit_issues [] 79
# data/maildir/steffes-j/clinton_energy [] 1
# data/maildir/steffes-j/inbox [] 482
# data/maildir/steffes-j/nerc [] 35
# data/maildir/steffes-j/show_cause [] 1
# data/maildir/steffes-j/icap_policy [] 1
# data/maildir/steffes-j/illinois [] 1
# data/maildir/steffes-j/michigan [] 1
# data/maildir/steffes-j/mbr___market_power [] 1
# data/maildir/schoolcraft-d ['nng', 'tw', 'tw_lft', 'sent_items', '_sent_mail', 'deleted_items', 'cas', 'outages', 'untitled', 'tw_fuel_sales', 'inbox', 'phffu'] 0
# data/maildir/schoolcraft-d/nng [] 1
# data/maildir/schoolcraft-d/tw ['tw_map'] 23
# data/maildir/schoolcraft-d/tw/tw_map [] 1
# data/maildir/schoolcraft-d/tw_lft [] 1
# data/maildir/schoolcraft-d/sent_items [] 481
# data/maildir/schoolcraft-d/_sent_mail [] 38
# data/maildir/schoolcraft-d/deleted_items [] 608
# data/maildir/schoolcraft-d/cas [] 1
# data/maildir/schoolcraft-d/outages ['mileage_expense'] 1
# data/maildir/schoolcraft-d/outages/mileage_expense [] 1
# data/maildir/schoolcraft-d/untitled [] 1
# data/maildir/schoolcraft-d/tw_fuel_sales ['tw_bullets'] 43
# data/maildir/schoolcraft-d/tw_fuel_sales/tw_bullets ['tw_park___ride'] 4
# data/maildir/schoolcraft-d/tw_fuel_sales/tw_bullets/tw_park___ride [] 1
# data/maildir/schoolcraft-d/inbox ['junk', 'citizens_griffith'] 95
# data/maildir/schoolcraft-d/inbox/junk [] 556
# data/maildir/schoolcraft-d/inbox/citizens_griffith [] 2
# data/maildir/schoolcraft-d/phffu [] 1
# data/maildir/ring-r ['eesirenewableenergy', 'eesi_deleted_documents', 'eesiisonewengland', 'eesimarketstexas', 'eesidealsgsaregion1', 'sent_items', 'deleted_items', 'eesiisonewyork', 'outbox', 'eesiisopjm', 'eesiphysicalpowerdelivery', 'personalfolder', 'inbox'] 0
# data/maildir/ring-r/eesirenewableenergy [] 296
# data/maildir/ring-r/eesi_deleted_documents [] 59
# data/maildir/ring-r/eesiisonewengland [] 10
# data/maildir/ring-r/eesimarketstexas [] 2
# data/maildir/ring-r/eesidealsgsaregion1 [] 37
# data/maildir/ring-r/sent_items [] 51
# data/maildir/ring-r/deleted_items [] 286
# data/maildir/ring-r/eesiisonewyork [] 4
# data/maildir/ring-r/outbox [] 1
# data/maildir/ring-r/eesiisopjm [] 38
# data/maildir/ring-r/eesiphysicalpowerdelivery [] 6
# data/maildir/ring-r/personalfolder [] 118
# data/maildir/ring-r/inbox ['eesiresponsesrfp'] 85
# data/maildir/ring-r/inbox/eesiresponsesrfp [] 1
# data/maildir/motley-m ['sent_items', 'deleted_items', 'inbox'] 0
# data/maildir/motley-m/sent_items [] 13
# data/maildir/motley-m/deleted_items [] 125
# data/maildir/motley-m/inbox ['ene_houston', 'broker_quotes', 'ene_portland'] 75
# data/maildir/motley-m/inbox/ene_houston ['west_gas'] 7
# data/maildir/motley-m/inbox/ene_houston/west_gas [] 5
# data/maildir/motley-m/inbox/broker_quotes [] 8
# data/maildir/motley-m/inbox/ene_portland ['fundies', 'risk_reports', 'credit', 'belden', 'administrative', 'middle_market'] 0
# data/maildir/motley-m/inbox/ene_portland/fundies [] 3
# data/maildir/motley-m/inbox/ene_portland/risk_reports [] 31
# data/maildir/motley-m/inbox/ene_portland/credit [] 5
# data/maildir/motley-m/inbox/ene_portland/belden [] 21
# data/maildir/motley-m/inbox/ene_portland/administrative [] 55
# data/maildir/motley-m/inbox/ene_portland/middle_market [] 30
# data/maildir/brawner-s ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'to_do', 'tasks', 'notes_inbox', 'sent', 'discussion_threads', 'john_memos', 'misc', 'inbox', 'contract'] 0
# data/maildir/brawner-s/sent_items [] 73
# data/maildir/brawner-s/_sent_mail [] 145
# data/maildir/brawner-s/all_documents [] 183
# data/maildir/brawner-s/deleted_items [] 240
# data/maildir/brawner-s/to_do [] 1
# data/maildir/brawner-s/tasks [] 1
# data/maildir/brawner-s/notes_inbox [] 35
# data/maildir/brawner-s/sent [] 130
# data/maildir/brawner-s/discussion_threads [] 103
# data/maildir/brawner-s/john_memos [] 1
# data/maildir/brawner-s/misc [] 10
# data/maildir/brawner-s/inbox [] 100
# data/maildir/brawner-s/contract [] 4
# data/maildir/watson-k ['top_shippers', 'order_637', 'contact_emp__list', 'enron_online', 'nng', 'e_mail_bin', 'elpaso_pipeline', 'industry_mentions', 'drafts__lotus_notes_', 'credit_union', 'glen_hass', 'agave', 'tw_cas', 'sent_items', 'payroll_electronic_directions', 'desert_crossing_storage', 'tw_rate_matrix', 'capacity_release', 'aquila_red_lake_storage', 'pros', 'keyex_1997', 'interconnect_agreement_sample', 'tw_options_sales_program', 'deleted_items', 'tw_hedges', 'tw_imbalances', 'rm_science_review', 'san_juan_expansion', 'sun_devil_expansion', 'italy', 'kingman_heat_recovery', 'vinson___elkins', 'pba_s', 'paris', 'ethink', 'nymex_prices', 'red_rock', 'big_sandy___caithness', 'negotiated_rates', 'tw_weekly_report', 'citizens', 'strategic_model', 'customer_list', 'tw_throughput_analysis', 'mike_reynolds', 'capacity', 'california', 'gri_jan_1996', 'girls', 'pemex_trans_pecos', 'usgt', 'weather', 'holidays', 'daily_balancing_report', 'rm_work_order', 'on_call_schedule', 'questar', 'sap', 'socalgas', 'business_objects', 'park__n_ride', 'dra', 'tw_outages', 'expense_rpts__1997', 'inbox', 'operational_sales', 'account_assignments', 'alternate_delivery_by_price', 'funny'] 0
# data/maildir/watson-k/top_shippers [] 3
# data/maildir/watson-k/order_637 [] 3
# data/maildir/watson-k/contact_emp__list [] 9
# data/maildir/watson-k/enron_online [] 8
# data/maildir/watson-k/nng [] 1
# data/maildir/watson-k/e_mail_bin [] 614
# data/maildir/watson-k/elpaso_pipeline [] 24
# data/maildir/watson-k/industry_mentions [] 19
# data/maildir/watson-k/drafts__lotus_notes_ [] 1
# data/maildir/watson-k/credit_union [] 1
# data/maildir/watson-k/glen_hass [] 6
# data/maildir/watson-k/agave [] 5
# data/maildir/watson-k/tw_cas [] 1
# data/maildir/watson-k/sent_items [] 971
# data/maildir/watson-k/payroll_electronic_directions [] 1
# data/maildir/watson-k/desert_crossing_storage [] 1
# data/maildir/watson-k/tw_rate_matrix [] 3
# data/maildir/watson-k/capacity_release [] 15
# data/maildir/watson-k/aquila_red_lake_storage [] 2
# data/maildir/watson-k/pros [] 1
# data/maildir/watson-k/keyex_1997 [] 2
# data/maildir/watson-k/interconnect_agreement_sample [] 1
# data/maildir/watson-k/tw_options_sales_program [] 2
# data/maildir/watson-k/deleted_items [] 422
# data/maildir/watson-k/tw_hedges [] 1
# data/maildir/watson-k/tw_imbalances [] 14
# data/maildir/watson-k/rm_science_review [] 5
# data/maildir/watson-k/san_juan_expansion [] 2
# data/maildir/watson-k/sun_devil_expansion [] 1
# data/maildir/watson-k/italy [] 10
# data/maildir/watson-k/kingman_heat_recovery [] 1
# data/maildir/watson-k/vinson___elkins [] 2
# data/maildir/watson-k/pba_s [] 1
# data/maildir/watson-k/paris [] 13
# data/maildir/watson-k/ethink [] 1
# data/maildir/watson-k/nymex_prices [] 10
# data/maildir/watson-k/red_rock [] 1
# data/maildir/watson-k/big_sandy___caithness [] 20
# data/maildir/watson-k/negotiated_rates [] 3
# data/maildir/watson-k/tw_weekly_report [] 9
# data/maildir/watson-k/citizens [] 3
# data/maildir/watson-k/strategic_model [] 1
# data/maildir/watson-k/customer_list [] 2
# data/maildir/watson-k/tw_throughput_analysis [] 1
# data/maildir/watson-k/mike_reynolds [] 1
# data/maildir/watson-k/capacity [] 4
# data/maildir/watson-k/california [] 61
# data/maildir/watson-k/gri_jan_1996 [] 1
# data/maildir/watson-k/girls [] 3
# data/maildir/watson-k/pemex_trans_pecos [] 15
# data/maildir/watson-k/usgt [] 2
# data/maildir/watson-k/weather [] 1
# data/maildir/watson-k/holidays [] 1
# data/maildir/watson-k/daily_balancing_report [] 23
# data/maildir/watson-k/rm_work_order [] 21
# data/maildir/watson-k/on_call_schedule [] 2
# data/maildir/watson-k/questar [] 35
# data/maildir/watson-k/sap [] 1
# data/maildir/watson-k/socalgas [] 1
# data/maildir/watson-k/business_objects [] 1
# data/maildir/watson-k/park__n_ride [] 5
# data/maildir/watson-k/dra [] 1
# data/maildir/watson-k/tw_outages [] 18
# data/maildir/watson-k/expense_rpts__1997 [] 6
# data/maildir/watson-k/inbox [] 500
# data/maildir/watson-k/operational_sales [] 27
# data/maildir/watson-k/account_assignments [] 1
# data/maildir/watson-k/alternate_delivery_by_price [] 1
# data/maildir/watson-k/funny [] 1
# data/maildir/guzman-m ['_sent_mail', 'all_documents', 'notes_inbox', 'discussion_threads'] 0
# data/maildir/guzman-m/_sent_mail [] 352
# data/maildir/guzman-m/all_documents [] 2067
# data/maildir/guzman-m/notes_inbox [] 1708
# data/maildir/guzman-m/discussion_threads [] 1927
# data/maildir/whalley-g ['mariner', 'sent_items', 'connect_deletes', 'economics', 'merchant_investments', '_sent_mail', 'contacts', 'all_documents', 'deleted_items', 'to_do', 'tasks', 'test', 'calendar', 'notes_inbox', 'sent', 'markets', 'personal', 'controls', 'discussion_threads', 'india', 'inbox'] 0
# data/maildir/whalley-g/mariner [] 5
# data/maildir/whalley-g/sent_items [] 68
# data/maildir/whalley-g/connect_deletes [] 172
# data/maildir/whalley-g/economics [] 4
# data/maildir/whalley-g/merchant_investments [] 3
# data/maildir/whalley-g/_sent_mail [] 24
# data/maildir/whalley-g/contacts [] 1
# data/maildir/whalley-g/all_documents [] 330
# data/maildir/whalley-g/deleted_items [] 66
# data/maildir/whalley-g/to_do [] 13
# data/maildir/whalley-g/tasks [] 3
# data/maildir/whalley-g/test ['contacts', 'tasks', 'calendar'] 0
# data/maildir/whalley-g/test/contacts [] 1
# data/maildir/whalley-g/test/tasks [] 2
# data/maildir/whalley-g/test/calendar [] 99
# data/maildir/whalley-g/calendar [] 149
# data/maildir/whalley-g/notes_inbox [] 94
# data/maildir/whalley-g/sent [] 38
# data/maildir/whalley-g/markets [] 26
# data/maildir/whalley-g/personal [] 1
# data/maildir/whalley-g/controls [] 1
# data/maildir/whalley-g/discussion_threads [] 313
# data/maildir/whalley-g/india [] 3
# data/maildir/whalley-g/inbox [] 462
# data/maildir/holst-k ['sent_items', 'deleted_items', 'inbox'] 0
# data/maildir/holst-k/sent_items [] 36
# data/maildir/holst-k/deleted_items [] 235
# data/maildir/holst-k/inbox [] 192
# data/maildir/townsend-j ['sent_items', '_sent_mail', 'all_documents', 'deleted_items', 'to_do', 'notes_inbox', 'sent', 'discussion_threads', 'inbox'] 0
# data/maildir/townsend-j/sent_items [] 16
# data/maildir/townsend-j/_sent_mail [] 34
# data/maildir/townsend-j/all_documents [] 78
# data/maildir/townsend-j/deleted_items [] 132
# data/maildir/townsend-j/to_do [] 2
# data/maildir/townsend-j/notes_inbox [] 33
# data/maildir/townsend-j/sent [] 32
# data/maildir/townsend-j/discussion_threads [] 76
# data/maildir/townsend-j/inbox [] 243
# data/maildir/kaminski-v ['azurix', 'var', 'newsletter', 'australia', 'duffie', 'sites', 'sent_items', 'publications', 'universities', 'stanford', 'ferc', '_sent_mail', 'ut', 'poland', 'gpg', 'uh', 'london', 'all_documents', 'deleted_items', 'credit', 'esai', 'consultants', 'ei', 'ees', 'risk', 'tasks', 'technical', 'fasb133', 'cera', 'evaluation', 'eci', 'calendar', 'conferences', 'rac', 'pjm', 'notes_inbox', 'sent', 'presentations', 'weather', 'c', 'personal', 'discussion_threads', 'rice', 'audit', 'accounting', 'untitledmartin', 'resumes', 'inbox'] 0
# data/maildir/kaminski-v/azurix ['azurix'] 0
# data/maildir/kaminski-v/azurix/azurix [] 3
# data/maildir/kaminski-v/var [] 110
# data/maildir/kaminski-v/newsletter [] 14
# data/maildir/kaminski-v/australia [] 112
# data/maildir/kaminski-v/duffie [] 5
# data/maildir/kaminski-v/sites [] 30
# data/maildir/kaminski-v/sent_items [] 1696
# data/maildir/kaminski-v/publications [] 4
# data/maildir/kaminski-v/universities [] 367
# data/maildir/kaminski-v/stanford [] 76
# data/maildir/kaminski-v/ferc [] 3
# data/maildir/kaminski-v/_sent_mail [] 3464
# data/maildir/kaminski-v/ut [] 76
# data/maildir/kaminski-v/poland [] 9
# data/maildir/kaminski-v/gpg [] 19
# data/maildir/kaminski-v/uh [] 7
# data/maildir/kaminski-v/london [] 195
# data/maildir/kaminski-v/all_documents [] 7174
# data/maildir/kaminski-v/deleted_items [] 1792
# data/maildir/kaminski-v/credit [] 65
# data/maildir/kaminski-v/esai [] 25
# data/maildir/kaminski-v/consultants [] 44
# data/maildir/kaminski-v/ei [] 51
# data/maildir/kaminski-v/ees [] 23
# data/maildir/kaminski-v/risk [] 54
# data/maildir/kaminski-v/tasks [] 1
# data/maildir/kaminski-v/technical [] 7
# data/maildir/kaminski-v/fasb133 [] 6
# data/maildir/kaminski-v/cera [] 28
# data/maildir/kaminski-v/evaluation [] 57
# data/maildir/kaminski-v/eci ['eci'] 1
# data/maildir/kaminski-v/eci/eci [] 108
# data/maildir/kaminski-v/calendar [] 62
# data/maildir/kaminski-v/conferences [] 223
# data/maildir/kaminski-v/rac ['rac'] 1
# data/maildir/kaminski-v/rac/rac [] 23
# data/maildir/kaminski-v/pjm [] 17
# data/maildir/kaminski-v/notes_inbox [] 223
# data/maildir/kaminski-v/sent [] 3463
# data/maildir/kaminski-v/presentations [] 21
# data/maildir/kaminski-v/weather [] 21
# data/maildir/kaminski-v/c ['technote', 'mangmt'] 0
# data/maildir/kaminski-v/c/technote ['mail'] 0
# data/maildir/kaminski-v/c/technote/mail ['projects', 'techmemos'] 0
# data/maildir/kaminski-v/c/technote/mail/projects [] 379
# data/maildir/kaminski-v/c/technote/mail/techmemos [] 187
# data/maildir/kaminski-v/c/mangmt ['group', 'ene_ect'] 0
# data/maildir/kaminski-v/c/mangmt/group ['software', 'management'] 0
# data/maildir/kaminski-v/c/mangmt/group/software ['management'] 0
# data/maildir/kaminski-v/c/mangmt/group/software/management [] 276
# data/maildir/kaminski-v/c/mangmt/group/management [] 526
# data/maildir/kaminski-v/c/mangmt/ene_ect [] 288
# data/maildir/kaminski-v/personal [] 281
# data/maildir/kaminski-v/discussion_threads [] 5550
# data/maildir/kaminski-v/rice [] 175
# data/maildir/kaminski-v/audit [] 7
# data/maildir/kaminski-v/accounting [] 1
# data/maildir/kaminski-v/untitledmartin [] 8
# data/maildir/kaminski-v/resumes [] 547
# data/maildir/kaminski-v/inbox [] 560

# %% [markdown]
# Now, let's parse a single email message:

# %%
from email.parser import Parser

file_to_read = rootdir + "/lay-k/all_documents/1."

with open(file_to_read, "r") as f:
    data = f.read()

#print(data)

email = Parser().parsestr(data)

print("\nTo: " , email['to'])
print("\n From: " , email['from'])

print("\n Subject: " , email['subject'])

print("\n \n Body: " , email.get_payload())
# Out:
# To:  mmilken@knowledgeu.com
#
#  From:  rosalee.fleming@enron.com
#
#  Subject:  Re: testing
#
#
#  Body:  Hi -
#
# We did receive the e-mail.
#
# Rosalee for Ken Lay
#
#
#
#
#
# "Michael Milken" <mmilken@knowledgeu.com> on 07/02/99 10:21:40 AM
# To: Kenneth Lay/Corp/Enron@Enron
# cc:
# Subject: testing

# %% [markdown]
# ### The MailMessage dataclass

# %% [markdown]
# I'm going to try something else new - a data class.

# %%
from dataclasses import dataclass, field
from typing import List

# %%
@dataclass
class MailMessage:
    to_addr: List[str] = field(default_factory=list)
    from_addr: str = field(default_factory=str)
    subject: str = field(default_factory=str)
    body: str = field(default_factory=str)

# %% [markdown]
# #### Usage examples

# %%
# Single address
myMsg = MailMessage('mickey@mouse.com', 'daffy@duck.com', 'Lunch tomorrow?', 'Burgers at Five Guys around noon?')
print(myMsg)
myMsg.to_addr
# Out:
# MailMessage(to_addr='mickey@mouse.com', from_addr='daffy@duck.com', subject='Lunch tomorrow?', body='Burgers at Five Guys around noon?')
# 'mickey@mouse.com'

# %%
# multiple address
myMsg = MailMessage(['mickey@mouse.com', 'minnie@mouse.com'], 'daffy@duck.com', 'Lunch tomorrow?', 'Burgers at Five Guys around noon?')
print(myMsg)
myMsg.to_addr
# Out:
# MailMessage(to_addr=['mickey@mouse.com', 'minnie@mouse.com'], from_addr='daffy@duck.com', subject='Lunch tomorrow?', body='Burgers at Five Guys around noon?')
# ['mickey@mouse.com', 'minnie@mouse.com']

# %% [markdown]
# ---
# Hmmmm... What does a multiple to: line look like? By inspection in a text editor, it looks like #7 has multiples.

# %%
file_to_read = rootdir + "/lay-k/all_documents/7."

with open(file_to_read, "r") as f:
    data = f.read()

#print(data)

email = Parser().parsestr(data)

email['to']
# Out:
# 'gary.fitch@enron.com, joan.richard@enron.com, steven.kean@enron.com, \n\tbill.donovan@enron.com, anna.harris@enron.com'

# %% [markdown]
# OK, I see ',' and '\n\t'. We might be able to make some assumptions about that structure to make code more efficient if this gets really painful.

# %% [markdown]
# ## A function to parse each email and return a MailMessage object:

# %%
def email_analyse(inputfile):
    with open(inputfile, "r", encoding = "ISO-8859-1") as f:
        data = f.read()

    email = Parser().parsestr(data)
    
    if email['to']:
        email_to = email['to']
        email_to = email_to.replace("\n", "")
        email_to = email_to.replace("\t", "")
        email_to = email_to.replace(" ", "")

        email_to = email_to.split(",")
    else:
        email_to = []

    from_email = email['from']

    email_body = email.get_payload()
    email_subject = email['subject']
    return MailMessage(email_to, from_email, email_subject, email_body)

# %% [markdown]
# ## Function to return a list of files with full path

# %%
import pathlib
def pathlist(rootdir):
    path_list = []
    for directory, subdirectory, filenames in  os.walk(rootdir):
        for name in filenames:
            if name != '.DS_Store':
                path_list.append(pathlib.PurePath(directory, name))
    return path_list
        
file_list = pathlist(rootdir)
print(file_list[0])
print(len(file_list))
# Out:
# data/maildir/rodrique-r/dublin/13.
# 517401

# %% [markdown]
# ---
# Now, let's test on our two cases above:

# %%
msg1 = email_analyse(rootdir + "/lay-k/all_documents/1.")
msg2 = email_analyse(rootdir + "/lay-k/all_documents/7.")
print(msg1)
print('\n\n')
print(msg2)
# Out:
# MailMessage(to_addr=['mmilken@knowledgeu.com'], from_addr='rosalee.fleming@enron.com', subject='Re: testing', body='Hi -\n\nWe did receive the e-mail.\n\nRosalee for Ken Lay\n\n\n\n\n\n"Michael Milken" <mmilken@knowledgeu.com> on 07/02/99 10:21:40 AM\nTo: Kenneth Lay/Corp/Enron@Enron\ncc:  \nSubject: testing\n\n\n\n\n\n\n')
#
#
#
# MailMessage(to_addr=['gary.fitch@enron.com', 'joan.richard@enron.com', 'steven.kean@enron.com', 'bill.donovan@enron.com', 'anna.harris@enron.com'], from_addr='rosalee.fleming@enron.com', subject='Persons Authorized to Approve Use of the Company Planes', body='FURTHER CLARIFICATION TO THE MESSAGE BELOW, for PERSONAL AIRCRAFT USE, the \nmembers of the Office of the Chairman must approve the requests.  In addition \nto Ken and Jeff, Joe Sutton will also approve personal requests.\n\n\nThis is the revised list of persons authorized to approve use of the company \nplane.  If there is a duplicate request for a plane, one of the members of \nthe Office of the Chairman  (Ken, Jeff or Joe) will determine priority.\n\n\nCliff Baxter\nMark Frevert\nKevin Hannon\nKen Harrison\nJoe Hirko\nStan Horton\nKen Lay\nRebecca Mark\nMark Metts\nLou Pai\nKen Rice \nJeff Skilling\nJoe Sutton\nTom White \n\nPlease call if you have any questions.\n\nRosalee')

# %% [markdown]
# ---
#
# Looks like that worked pretty well. Let's try a run to see how long it takes.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Important::</b> May not want to do this as a live demo. It takes a minute or two.
# </div>

# %%
# %%time
mail_list = []
for fname in file_list:
    msg = email_analyse(fname)
    mail_list.append(msg)
# Out:
# CPU times: user 58.9 s, sys: 3.79 s, total: 1min 2s
# Wall time: 1min 2s

# %% [markdown]
# **Note:** Copied from earlier run on 2017 MacBook Pro
#
# ```
# CPU times: user 1min 47s, sys: 59.5 s, total: 2min 46s
# Wall time: 5min 16s
# ```
#
# **Current Frankenbox:**
# ```
# CPU times: user 1min 6s, sys: 5.42 s, total: 1min 12s
# Wall time: 1min 13s
# ```

# %% [markdown]
# ## Pympler -- Showing object size

# %% [markdown]
# [Pympler docs](https://pympler.readthedocs.io/en/latest/)
#
# >Pympler is a development tool to measure, monitor and analyze the memory behavior of Python objects in a running Python application.
# >
# >By pympling a Python application, detailed insight in the size and the lifetime of Python objects can be obtained. Undesirable or unexpected runtime behavior like memory bloat and other “pymples” can easily be identified.

# %%
# !pip install pympler
# Out:
# Collecting pympler
#   Using cached Pympler-0.9-py3-none-any.whl
# Installing collected packages: pympler
# Successfully installed pympler-0.9

# %%
from pympler import asizeof
mail_size = asizeof.asizeof(mail_list)
print(f'{len(mail_list)} objects totalling {mail_size} bytes')
del mail_list
# Out:
# 517401 objects totalling 1470658408 bytes

# %% [markdown]
# # Now, let's parallel-ize it

# %% [markdown]
# ## Process Pool

# %%
from multiprocessing import Pool, Process, cpu_count

# %%
processes = []
workers = cpu_count()
workers
# Out:
# 32

# %%
# %%time
with Pool(workers) as p:
    result = p.map(email_analyse, file_list)
    
print(len(result))
# Out:
# 517401
# CPU times: user 4.97 s, sys: 1.77 s, total: 6.74 s
# Wall time: 7.25 s

# %%
result[0]
# Out:
# MailMessage(to_addr=['gary.stadler@enron.com', 'gabriel.monroy@enron.com', 'robin.rodrigue@enron.com'], from_addr='c.griffin@enron.com', subject='EES Volumetric Positions', body="Attached are  EES's Volumetric NYMEX and Basis positions for 7/17/2000.   \n\n\n\n\nRobin, I'm expecting our position to be a little shorter (by about 30 \ncontracts for Nymex).  Please contact me at x3-5070 if you have any questions.\n\nThanks,\n\nMonica for Kyle\n")

# %% [markdown]
# ## Manually Multiprocessing

# %%
len (file_list)
# Out:
# 517401

# %%
len(file_list) // workers # Integer division
# Out:
# 16168

# %%
def process_files(file_list):
    for f in file_list:
        email_analyse(f)

# %%
# %%time
for i in range(0, workers):
    sub_list = [file_list[j] for j in range(0, len(file_list)) if j % workers == i]
    if len(sub_list) > 0:
        p = Process(target=process_files, args=(sub_list,))
        p.start()
        processes.append(p)
    # input_file_list.put('STOP')


# Wait for processes to stop
for p in processes:
    p.join()
# Out:
# CPU times: user 1.45 s, sys: 1.48 s, total: 2.93 s
# Wall time: 5.73 s

# %% [markdown]
# * **Numba**: is a performance library made by Anaconda. It is generally used to compile CPU-intensive math functions in Python. Numba can also be used to **turn off the GIL**, parallelize loops, and leverage the GPU.
#
# * **Concurrent.futures**: A higher-level interface to the Multiprocessing library. This article was originally written for concurrent.futures, however a change in Python 3.8 affected the way it runs. If you are running a Python version **other** than 3.8, you may want to give it a try.
#
# * **Deco**: [Deco](https://github.com/alex-sherman/deco) (DEcorated COncurrency) is "A simplified parallel computing model for Python. DECO automatically parallelizes Python programs, and requires minimal modifications to existing serial programs." Suffers from the same Python 3.8 problem as concurrent.futures.

# %% [markdown]
# # Demo: Practical application -- Extracting Point Clouds from Video

# %% [markdown]
# # Other alternatives
